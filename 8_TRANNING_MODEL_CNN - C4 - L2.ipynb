# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import SGD

# %%
# Directorios de entrenamiento, validación y prueba TAMBIEN MODIFICAR NUM_CLASS Y BEST_MODEL 
train_dir = r'D:\Python\TESIS\CLUSTERS_C4_CALC_K\train'
val_dir = r'D:\Python\TESIS\CLUSTERS_C4_CALC_K\val'
test_dir = r'D:\Python\TESIS\CLUSTERS_C4_CALC_K\test'

# %%
# Configurar TensorFlow para que use solo la GPU 0 y optimizar el uso de la memoria
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU configurada correctamente.")
    except RuntimeError as e:
        print(e)

# Parámetros de la red y del entrenamiento
img_width, img_height = 170, 170  # Ajustado al lienzo de 170x170 píxeles
batch_size = 64
epochs = 100
num_classes = 10  # Número de categorías
l2 = 0.02 

# Generadores de datos para la carga y preprocesamiento de imágenes en escala de grises
train_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Generadores para train, val y test
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)  # No se necesita barajar para evaluar
# Out:
# GPU configurada correctamente.
# Found 16479 images belonging to 10 classes.
# Found 4706 images belonging to 10 classes.
# Found 2362 images belonging to 10 classes.

# %%
# Crear el modelo
model = Sequential()

# Primera capa convolucional con regularización L2
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 1), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Segunda capa convolucional con regularización L2
model.add(Conv2D(32, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Tercera capa convolucional con regularización L2
model.add(Conv2D(64, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))

# Cuarta capa convolucional con regularización L2
model.add(Conv2D(64, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Aplanar las capas convolucionales para conectarlas con capas densas
model.add(Flatten())

# Capa densa con regularización L2 y Dropout
model.add(Dense(128, kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Capa de salida
model.add(Dense(num_classes, kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('softmax'))

# Compilar el modelo con el optimizador SGD, una tasa de aprendizaje inicial baja y decaimiento
#optimizer = SGD(learning_rate=1e-4, momentum=0.9, decay=1e-6)
optimizer=Adam(learning_rate=1e-4)

# Configuración del modelo de entrenamiento
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Callbacks para guardar el mejor modelo y detener temprano
checkpoint = ModelCheckpoint('best_model_C4.h5', verbose=1, save_best_only=True, monitor='val_loss', mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

# Entrenamiento del modelo
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[checkpoint, early_stopping],
    workers=tf.data.experimental.AUTOTUNE,
    use_multiprocessing=True)

# Evaluación del modelo en el conjunto de prueba
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# 257/257 [==============================] - ETA: 0s - loss: 4.7620 - accuracy: 0.6482
# Epoch 1: val_loss improved from inf to 2.28413, saving model to best_model_C4.h5
# 257/257 [==============================] - 42s 150ms/step - loss: 4.7620 - accuracy: 0.6482 - val_loss: 2.2841 - val_accuracy: 0.9165
# Epoch 2/100
# 257/257 [==============================] - ETA: 0s - loss: 1.8439 - accuracy: 0.9120
# Epoch 2: val_loss improved from 2.28413 to 1.38462, saving model to best_model_C4.h5
# 257/257 [==============================] - 34s 133ms/step - loss: 1.8439 - accuracy: 0.9120 - val_loss: 1.3846 - val_accuracy: 0.9435
# Epoch 3/100
# 257/257 [==============================] - ETA: 0s - loss: 1.2206 - accuracy: 0.9284
# Epoch 3: val_loss improved from 1.38462 to 0.97253, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 126ms/step - loss: 1.2206 - accuracy: 0.9284 - val_loss: 0.9725 - val_accuracy: 0.9602
# Epoch 4/100
# 257/257 [==============================] - ETA: 0s - loss: 0.9331 - accuracy: 0.9332
# Epoch 4: val_loss improved from 0.97253 to 0.78341, saving model to best_model_C4.h5
# 257/257 [==============================] - 34s 131ms/step - loss: 0.9331 - accuracy: 0.9332 - val_loss: 0.7834 - val_accuracy: 0.9589
# Epoch 5/100
# 257/257 [==============================] - ETA: 0s - loss: 0.7809 - accuracy: 0.9369
# Epoch 5: val_loss improved from 0.78341 to 0.65807, saving model to best_model_C4.h5
# 257/257 [==============================] - 33s 128ms/step - loss: 0.7809 - accuracy: 0.9369 - val_loss: 0.6581 - val_accuracy: 0.9673
# Epoch 6/100
# 257/257 [==============================] - ETA: 0s - loss: 0.6914 - accuracy: 0.9409
# Epoch 6: val_loss improved from 0.65807 to 0.59934, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 125ms/step - loss: 0.6914 - accuracy: 0.9409 - val_loss: 0.5993 - val_accuracy: 0.9630
# Epoch 7/100
# 257/257 [==============================] - ETA: 0s - loss: 0.6376 - accuracy: 0.9408
# Epoch 7: val_loss improved from 0.59934 to 0.55894, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 126ms/step - loss: 0.6376 - accuracy: 0.9408 - val_loss: 0.5589 - val_accuracy: 0.9647
# Epoch 8/100
# 257/257 [==============================] - ETA: 0s - loss: 0.6070 - accuracy: 0.9395
# Epoch 8: val_loss improved from 0.55894 to 0.52999, saving model to best_model_C4.h5
# 257/257 [==============================] - 33s 130ms/step - loss: 0.6070 - accuracy: 0.9395 - val_loss: 0.5300 - val_accuracy: 0.9655
# Epoch 9/100
# 257/257 [==============================] - ETA: 0s - loss: 0.5757 - accuracy: 0.9427
# Epoch 9: val_loss improved from 0.52999 to 0.50860, saving model to best_model_C4.h5
# 257/257 [==============================] - 31s 122ms/step - loss: 0.5757 - accuracy: 0.9427 - val_loss: 0.5086 - val_accuracy: 0.9670
# Epoch 10/100
# 257/257 [==============================] - ETA: 0s - loss: 0.5563 - accuracy: 0.9423
# Epoch 10: val_loss improved from 0.50860 to 0.49383, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 125ms/step - loss: 0.5563 - accuracy: 0.9423 - val_loss: 0.4938 - val_accuracy: 0.9675
# Epoch 11/100
# 257/257 [==============================] - ETA: 0s - loss: 0.5329 - accuracy: 0.9476
# Epoch 11: val_loss improved from 0.49383 to 0.47822, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 123ms/step - loss: 0.5329 - accuracy: 0.9476 - val_loss: 0.4782 - val_accuracy: 0.9692
# Epoch 12/100
# 257/257 [==============================] - ETA: 0s - loss: 0.5265 - accuracy: 0.9446
# Epoch 12: val_loss improved from 0.47822 to 0.46435, saving model to best_model_C4.h5
# 257/257 [==============================] - 31s 120ms/step - loss: 0.5265 - accuracy: 0.9446 - val_loss: 0.4643 - val_accuracy: 0.9683
# Epoch 13/100
# 257/257 [==============================] - ETA: 0s - loss: 0.5127 - accuracy: 0.9450
# Epoch 13: val_loss improved from 0.46435 to 0.46011, saving model to best_model_C4.h5
# 257/257 [==============================] - 31s 121ms/step - loss: 0.5127 - accuracy: 0.9450 - val_loss: 0.4601 - val_accuracy: 0.9649
# Epoch 14/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4999 - accuracy: 0.9490
# Epoch 14: val_loss improved from 0.46011 to 0.44941, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 123ms/step - loss: 0.4999 - accuracy: 0.9490 - val_loss: 0.4494 - val_accuracy: 0.9636
# Epoch 15/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4990 - accuracy: 0.9457
# Epoch 15: val_loss improved from 0.44941 to 0.44910, saving model to best_model_C4.h5
# 257/257 [==============================] - 31s 121ms/step - loss: 0.4990 - accuracy: 0.9457 - val_loss: 0.4491 - val_accuracy: 0.9645
# Epoch 16/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4874 - accuracy: 0.9494
# Epoch 16: val_loss improved from 0.44910 to 0.43661, saving model to best_model_C4.h5
# 257/257 [==============================] - 30s 115ms/step - loss: 0.4874 - accuracy: 0.9494 - val_loss: 0.4366 - val_accuracy: 0.9679
# Epoch 17/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4814 - accuracy: 0.9506
# Epoch 17: val_loss improved from 0.43661 to 0.42791, saving model to best_model_C4.h5
# 257/257 [==============================] - 31s 121ms/step - loss: 0.4814 - accuracy: 0.9506 - val_loss: 0.4279 - val_accuracy: 0.9664
# Epoch 18/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4725 - accuracy: 0.9489
# Epoch 18: val_loss did not improve from 0.42791
# 257/257 [==============================] - 31s 121ms/step - loss: 0.4725 - accuracy: 0.9489 - val_loss: 0.4553 - val_accuracy: 0.9527
# Epoch 19/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4699 - accuracy: 0.9514
# Epoch 19: val_loss improved from 0.42791 to 0.41924, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 123ms/step - loss: 0.4699 - accuracy: 0.9514 - val_loss: 0.4192 - val_accuracy: 0.9688
# Epoch 20/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4646 - accuracy: 0.9519
# Epoch 20: val_loss did not improve from 0.41924
# 257/257 [==============================] - 32s 123ms/step - loss: 0.4646 - accuracy: 0.9519 - val_loss: 0.4223 - val_accuracy: 0.9636
# Epoch 21/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4608 - accuracy: 0.9510
# Epoch 21: val_loss improved from 0.41924 to 0.41045, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 123ms/step - loss: 0.4608 - accuracy: 0.9510 - val_loss: 0.4104 - val_accuracy: 0.9694
# Epoch 22/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4543 - accuracy: 0.9533
# Epoch 22: val_loss improved from 0.41045 to 0.40954, saving model to best_model_C4.h5
# 257/257 [==============================] - 31s 122ms/step - loss: 0.4543 - accuracy: 0.9533 - val_loss: 0.4095 - val_accuracy: 0.9670
# Epoch 23/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4526 - accuracy: 0.9511
# Epoch 23: val_loss did not improve from 0.40954
# 257/257 [==============================] - 31s 119ms/step - loss: 0.4526 - accuracy: 0.9511 - val_loss: 0.4136 - val_accuracy: 0.9649
# Epoch 24/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.9524
# Epoch 24: val_loss improved from 0.40954 to 0.40649, saving model to best_model_C4.h5
# 257/257 [==============================] - 29s 114ms/step - loss: 0.4458 - accuracy: 0.9524 - val_loss: 0.4065 - val_accuracy: 0.9679
# Epoch 25/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4450 - accuracy: 0.9530
# Epoch 25: val_loss improved from 0.40649 to 0.40571, saving model to best_model_C4.h5
# 257/257 [==============================] - 30s 118ms/step - loss: 0.4450 - accuracy: 0.9530 - val_loss: 0.4057 - val_accuracy: 0.9666
# Epoch 26/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4428 - accuracy: 0.9519
# Epoch 26: val_loss did not improve from 0.40571
# 257/257 [==============================] - 31s 120ms/step - loss: 0.4428 - accuracy: 0.9519 - val_loss: 0.4076 - val_accuracy: 0.9655
# Epoch 27/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4395 - accuracy: 0.9527
# Epoch 27: val_loss improved from 0.40571 to 0.39353, saving model to best_model_C4.h5
# 257/257 [==============================] - 30s 118ms/step - loss: 0.4395 - accuracy: 0.9527 - val_loss: 0.3935 - val_accuracy: 0.9722
# Epoch 28/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4385 - accuracy: 0.9540
# Epoch 28: val_loss improved from 0.39353 to 0.39254, saving model to best_model_C4.h5
# 257/257 [==============================] - 31s 121ms/step - loss: 0.4385 - accuracy: 0.9540 - val_loss: 0.3925 - val_accuracy: 0.9688
# Epoch 29/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4355 - accuracy: 0.9532
# Epoch 29: val_loss did not improve from 0.39254
# 257/257 [==============================] - 30s 118ms/step - loss: 0.4355 - accuracy: 0.9532 - val_loss: 0.4103 - val_accuracy: 0.9636
# Epoch 30/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4338 - accuracy: 0.9534
# Epoch 30: val_loss improved from 0.39254 to 0.38887, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 124ms/step - loss: 0.4338 - accuracy: 0.9534 - val_loss: 0.3889 - val_accuracy: 0.9698
# Epoch 31/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4262 - accuracy: 0.9551
# Epoch 31: val_loss improved from 0.38887 to 0.38583, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 124ms/step - loss: 0.4262 - accuracy: 0.9551 - val_loss: 0.3858 - val_accuracy: 0.9694
# Epoch 32/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4248 - accuracy: 0.9537
# Epoch 32: val_loss did not improve from 0.38583
# 257/257 [==============================] - 32s 123ms/step - loss: 0.4248 - accuracy: 0.9537 - val_loss: 0.3986 - val_accuracy: 0.9595
# Epoch 33/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4251 - accuracy: 0.9542
# Epoch 33: val_loss improved from 0.38583 to 0.38133, saving model to best_model_C4.h5
# 257/257 [==============================] - 33s 127ms/step - loss: 0.4251 - accuracy: 0.9542 - val_loss: 0.3813 - val_accuracy: 0.9707
# Epoch 34/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4229 - accuracy: 0.9552
# Epoch 34: val_loss improved from 0.38133 to 0.38038, saving model to best_model_C4.h5
# 257/257 [==============================] - 31s 120ms/step - loss: 0.4229 - accuracy: 0.9552 - val_loss: 0.3804 - val_accuracy: 0.9726
# Epoch 35/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4214 - accuracy: 0.9541
# Epoch 35: val_loss improved from 0.38038 to 0.37991, saving model to best_model_C4.h5
# 257/257 [==============================] - 31s 122ms/step - loss: 0.4214 - accuracy: 0.9541 - val_loss: 0.3799 - val_accuracy: 0.9715
# Epoch 36/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4173 - accuracy: 0.9551
# Epoch 36: val_loss did not improve from 0.37991
# 257/257 [==============================] - 33s 129ms/step - loss: 0.4173 - accuracy: 0.9551 - val_loss: 0.3861 - val_accuracy: 0.9660
# Epoch 37/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4116 - accuracy: 0.9563
# Epoch 37: val_loss improved from 0.37991 to 0.37849, saving model to best_model_C4.h5
# 257/257 [==============================] - 35s 137ms/step - loss: 0.4116 - accuracy: 0.9563 - val_loss: 0.3785 - val_accuracy: 0.9664
# Epoch 38/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4130 - accuracy: 0.9549
# Epoch 38: val_loss did not improve from 0.37849
# 257/257 [==============================] - 33s 129ms/step - loss: 0.4130 - accuracy: 0.9549 - val_loss: 0.3835 - val_accuracy: 0.9632
# Epoch 39/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4109 - accuracy: 0.9552
# Epoch 39: val_loss improved from 0.37849 to 0.37753, saving model to best_model_C4.h5
# 257/257 [==============================] - 34s 131ms/step - loss: 0.4109 - accuracy: 0.9552 - val_loss: 0.3775 - val_accuracy: 0.9666
# Epoch 40/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4105 - accuracy: 0.9554
# Epoch 40: val_loss did not improve from 0.37753
# 257/257 [==============================] - 35s 135ms/step - loss: 0.4105 - accuracy: 0.9554 - val_loss: 0.3797 - val_accuracy: 0.9630
# Epoch 41/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4094 - accuracy: 0.9551
# Epoch 41: val_loss improved from 0.37753 to 0.37719, saving model to best_model_C4.h5
# 257/257 [==============================] - 34s 132ms/step - loss: 0.4094 - accuracy: 0.9551 - val_loss: 0.3772 - val_accuracy: 0.9649
# Epoch 42/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4020 - accuracy: 0.9569
# Epoch 42: val_loss improved from 0.37719 to 0.37537, saving model to best_model_C4.h5
# 257/257 [==============================] - 31s 122ms/step - loss: 0.4020 - accuracy: 0.9569 - val_loss: 0.3754 - val_accuracy: 0.9645
# Epoch 43/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4045 - accuracy: 0.9542
# Epoch 43: val_loss improved from 0.37537 to 0.36636, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 123ms/step - loss: 0.4045 - accuracy: 0.9542 - val_loss: 0.3664 - val_accuracy: 0.9688
# Epoch 44/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4019 - accuracy: 0.9566
# Epoch 44: val_loss did not improve from 0.36636
# 257/257 [==============================] - 34s 133ms/step - loss: 0.4019 - accuracy: 0.9566 - val_loss: 0.3725 - val_accuracy: 0.9696
# Epoch 45/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3985 - accuracy: 0.9564
# Epoch 45: val_loss improved from 0.36636 to 0.36444, saving model to best_model_C4.h5
# 257/257 [==============================] - 35s 135ms/step - loss: 0.3985 - accuracy: 0.9564 - val_loss: 0.3644 - val_accuracy: 0.9688
# Epoch 46/100
# 257/257 [==============================] - ETA: 0s - loss: 0.4001 - accuracy: 0.9566
# Epoch 46: val_loss improved from 0.36444 to 0.36062, saving model to best_model_C4.h5
# 257/257 [==============================] - 34s 134ms/step - loss: 0.4001 - accuracy: 0.9566 - val_loss: 0.3606 - val_accuracy: 0.9668
# Epoch 47/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3991 - accuracy: 0.9544
# Epoch 47: val_loss improved from 0.36062 to 0.35733, saving model to best_model_C4.h5
# 257/257 [==============================] - 34s 131ms/step - loss: 0.3991 - accuracy: 0.9544 - val_loss: 0.3573 - val_accuracy: 0.9692
# Epoch 48/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3981 - accuracy: 0.9543
# Epoch 48: val_loss did not improve from 0.35733
# 257/257 [==============================] - 34s 132ms/step - loss: 0.3981 - accuracy: 0.9543 - val_loss: 0.3581 - val_accuracy: 0.9677
# Epoch 49/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3897 - accuracy: 0.9577
# Epoch 49: val_loss did not improve from 0.35733
# 257/257 [==============================] - 33s 127ms/step - loss: 0.3897 - accuracy: 0.9577 - val_loss: 0.3614 - val_accuracy: 0.9690
# Epoch 50/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3929 - accuracy: 0.9560
# Epoch 50: val_loss improved from 0.35733 to 0.35235, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 124ms/step - loss: 0.3929 - accuracy: 0.9560 - val_loss: 0.3524 - val_accuracy: 0.9739
# Epoch 51/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3916 - accuracy: 0.9563
# Epoch 51: val_loss improved from 0.35235 to 0.35007, saving model to best_model_C4.h5
# 257/257 [==============================] - 34s 131ms/step - loss: 0.3916 - accuracy: 0.9563 - val_loss: 0.3501 - val_accuracy: 0.9696
# Epoch 52/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.9563
# Epoch 52: val_loss did not improve from 0.35007
# 257/257 [==============================] - 32s 124ms/step - loss: 0.3892 - accuracy: 0.9563 - val_loss: 0.3596 - val_accuracy: 0.9681
# Epoch 53/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3867 - accuracy: 0.9569
# Epoch 53: val_loss improved from 0.35007 to 0.34896, saving model to best_model_C4.h5
# 257/257 [==============================] - 35s 134ms/step - loss: 0.3867 - accuracy: 0.9569 - val_loss: 0.3490 - val_accuracy: 0.9692
# Epoch 54/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3867 - accuracy: 0.9561
# Epoch 54: val_loss did not improve from 0.34896
# 257/257 [==============================] - 35s 135ms/step - loss: 0.3867 - accuracy: 0.9561 - val_loss: 0.3491 - val_accuracy: 0.9711
# Epoch 55/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3831 - accuracy: 0.9588
# Epoch 55: val_loss did not improve from 0.34896
# 257/257 [==============================] - 32s 126ms/step - loss: 0.3831 - accuracy: 0.9588 - val_loss: 0.3498 - val_accuracy: 0.9692
# Epoch 56/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3807 - accuracy: 0.9592
# Epoch 56: val_loss improved from 0.34896 to 0.34265, saving model to best_model_C4.h5
# 257/257 [==============================] - 32s 124ms/step - loss: 0.3807 - accuracy: 0.9592 - val_loss: 0.3426 - val_accuracy: 0.9707
# Epoch 57/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3778 - accuracy: 0.9580
# Epoch 57: val_loss did not improve from 0.34265
# 257/257 [==============================] - 34s 131ms/step - loss: 0.3778 - accuracy: 0.9580 - val_loss: 0.3434 - val_accuracy: 0.9685
# Epoch 58/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3771 - accuracy: 0.9607
# Epoch 58: val_loss improved from 0.34265 to 0.33905, saving model to best_model_C4.h5
# 257/257 [==============================] - 36s 138ms/step - loss: 0.3771 - accuracy: 0.9607 - val_loss: 0.3391 - val_accuracy: 0.9720
# Epoch 59/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3731 - accuracy: 0.9597
# Epoch 59: val_loss did not improve from 0.33905
# 257/257 [==============================] - 36s 139ms/step - loss: 0.3731 - accuracy: 0.9597 - val_loss: 0.3392 - val_accuracy: 0.9662
# Epoch 60/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3762 - accuracy: 0.9572
# Epoch 60: val_loss improved from 0.33905 to 0.33767, saving model to best_model_C4.h5
# 257/257 [==============================] - 35s 136ms/step - loss: 0.3762 - accuracy: 0.9572 - val_loss: 0.3377 - val_accuracy: 0.9702
# Epoch 61/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3731 - accuracy: 0.9572
# Epoch 61: val_loss improved from 0.33767 to 0.33588, saving model to best_model_C4.h5
# 257/257 [==============================] - 34s 131ms/step - loss: 0.3731 - accuracy: 0.9572 - val_loss: 0.3359 - val_accuracy: 0.9732
# Epoch 62/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3713 - accuracy: 0.9574
# Epoch 62: val_loss improved from 0.33588 to 0.33584, saving model to best_model_C4.h5
# 257/257 [==============================] - 34s 133ms/step - loss: 0.3713 - accuracy: 0.9574 - val_loss: 0.3358 - val_accuracy: 0.9698
# Epoch 63/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.9585
# Epoch 63: val_loss did not improve from 0.33584
# 257/257 [==============================] - 34s 134ms/step - loss: 0.3696 - accuracy: 0.9585 - val_loss: 0.3359 - val_accuracy: 0.9709
# Epoch 64/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3708 - accuracy: 0.9566
# Epoch 64: val_loss improved from 0.33584 to 0.33460, saving model to best_model_C4.h5
# 257/257 [==============================] - 36s 139ms/step - loss: 0.3708 - accuracy: 0.9566 - val_loss: 0.3346 - val_accuracy: 0.9730
# Epoch 65/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3665 - accuracy: 0.9564
# Epoch 65: val_loss improved from 0.33460 to 0.32998, saving model to best_model_C4.h5
# 257/257 [==============================] - 36s 139ms/step - loss: 0.3665 - accuracy: 0.9564 - val_loss: 0.3300 - val_accuracy: 0.9707
# Epoch 66/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3622 - accuracy: 0.9604
# Epoch 66: val_loss did not improve from 0.32998
# 257/257 [==============================] - 36s 139ms/step - loss: 0.3622 - accuracy: 0.9604 - val_loss: 0.3370 - val_accuracy: 0.9645
# Epoch 67/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3643 - accuracy: 0.9573
# Epoch 67: val_loss did not improve from 0.32998
# 257/257 [==============================] - 34s 133ms/step - loss: 0.3643 - accuracy: 0.9573 - val_loss: 0.3427 - val_accuracy: 0.9658
# Epoch 68/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3640 - accuracy: 0.9576
# Epoch 68: val_loss improved from 0.32998 to 0.32500, saving model to best_model_C4.h5
# 257/257 [==============================] - 35s 136ms/step - loss: 0.3640 - accuracy: 0.9576 - val_loss: 0.3250 - val_accuracy: 0.9728
# Epoch 69/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.9585
# Epoch 69: val_loss did not improve from 0.32500
# 257/257 [==============================] - 30s 115ms/step - loss: 0.3603 - accuracy: 0.9585 - val_loss: 0.3301 - val_accuracy: 0.9692
# Epoch 70/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3615 - accuracy: 0.9600
# Epoch 70: val_loss improved from 0.32500 to 0.32495, saving model to best_model_C4.h5
# 257/257 [==============================] - 36s 140ms/step - loss: 0.3615 - accuracy: 0.9600 - val_loss: 0.3249 - val_accuracy: 0.9709
# Epoch 71/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3592 - accuracy: 0.9580
# Epoch 71: val_loss improved from 0.32495 to 0.32021, saving model to best_model_C4.h5
# 257/257 [==============================] - 36s 139ms/step - loss: 0.3592 - accuracy: 0.9580 - val_loss: 0.3202 - val_accuracy: 0.9739
# Epoch 72/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3594 - accuracy: 0.9558
# Epoch 72: val_loss did not improve from 0.32021
# 257/257 [==============================] - 34s 134ms/step - loss: 0.3594 - accuracy: 0.9558 - val_loss: 0.3302 - val_accuracy: 0.9698
# Epoch 73/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3592 - accuracy: 0.9602
# Epoch 73: val_loss did not improve from 0.32021
# 257/257 [==============================] - 33s 129ms/step - loss: 0.3592 - accuracy: 0.9602 - val_loss: 0.3213 - val_accuracy: 0.9711
# Epoch 74/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3554 - accuracy: 0.9583
# Epoch 74: val_loss did not improve from 0.32021
# 257/257 [==============================] - 35s 134ms/step - loss: 0.3554 - accuracy: 0.9583 - val_loss: 0.3225 - val_accuracy: 0.9700
# Epoch 75/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3527 - accuracy: 0.9591
# Epoch 75: val_loss did not improve from 0.32021
# 257/257 [==============================] - 37s 143ms/step - loss: 0.3527 - accuracy: 0.9591 - val_loss: 0.3224 - val_accuracy: 0.9688
# Epoch 76/100
# 257/257 [==============================] - ETA: 0s - loss: 0.3548 - accuracy: 0.9586
# Epoch 76: val_loss did not improve from 0.32021
# 257/257 [==============================] - 36s 141ms/step - loss: 0.3548 - accuracy: 0.9586 - val_loss: 0.3207 - val_accuracy: 0.9698
# Epoch 76: early stopping
# 37/37 [==============================] - 2s 64ms/step - loss: 0.3151 - accuracy: 0.9729
# Test Loss: 0.3150717616081238
# Test Accuracy: 0.9729043245315552

# %%
# Graficar precisión y pérdida
plt.figure(figsize=(12, 5))

# Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Línea para Test
plt.title('Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.text(len(history.history['accuracy']) - 1, test_accuracy, f'Test Accuracy: {test_accuracy:.2f}', color='r', ha='center')


# Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')  # Línea para Test
plt.title('Cross Entropy Loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.text(len(history.history['loss']) - 1, test_loss, f'Test Loss: {test_loss:.2f}', color='r', ha='center')

plt.show()
