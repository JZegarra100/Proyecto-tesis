# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt

# %%
# Directorios de entrenamiento, validación y prueba
train_dir = r'D:\Python\TESIS\CLUSTERS_C12_CALC_K\train'
val_dir = r'D:\Python\TESIS\CLUSTERS_C12_CALC_K\val'
test_dir = r'D:\Python\TESIS\CLUSTERS_C12_CALC_K\test'

# %%
# Configurar TensorFlow para que use solo la GPU 0 y optimizar el uso de la memoria
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU configurada correctamente.")
    except RuntimeError as e:
        print(e)

# Parámetros de la red y del entrenamiento
img_width, img_height = 170, 170  # Ajustado al lienzo de 170x170 píxeles
batch_size = 32
epochs = 50
num_classes = 2  # Número de categorías
# Out:
# GPU configurada correctamente.

# %%
# Generadores de datos para la carga y preprocesamiento de imágenes en escala de grises
train_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Generadores para train, val y test
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)  # No se necesita barajar para evaluar

# Construcción de la red neuronal convolucional
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# Configuración del modelo de entrenamiento
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=1e-4),
              metrics=['accuracy'])

# Callbacks para guardar el mejor modelo y detener temprano
checkpoint = ModelCheckpoint('best_model_C12.h5', verbose=1, save_best_only=True, monitor='val_loss', mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

# Entrenamiento del modelo
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[checkpoint, early_stopping],
    workers=tf.data.experimental.AUTOTUNE,
    use_multiprocessing=True)

# Evaluación del modelo en el conjunto de prueba
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Found 1000 images belonging to 2 classes.
# Found 165 images belonging to 2 classes.
# Found 84 images belonging to 2 classes.
# Epoch 1/50
# 31/31 [==============================] - ETA: 0s - loss: 0.6209 - accuracy: 0.6787
# Epoch 1: val_loss improved from inf to 0.50357, saving model to best_model_C12.h5
# 31/31 [==============================] - 5s 68ms/step - loss: 0.6209 - accuracy: 0.6787 - val_loss: 0.5036 - val_accuracy: 0.9187
# Epoch 2/50
# 31/31 [==============================] - ETA: 0s - loss: 0.4386 - accuracy: 0.8771
# Epoch 2: val_loss improved from 0.50357 to 0.39622, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 60ms/step - loss: 0.4386 - accuracy: 0.8771 - val_loss: 0.3962 - val_accuracy: 0.9625
# Epoch 3/50
# 30/31 [============================>.] - ETA: 0s - loss: 0.2918 - accuracy: 0.9271
# Epoch 3: val_loss improved from 0.39622 to 0.18703, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 63ms/step - loss: 0.2912 - accuracy: 0.9277 - val_loss: 0.1870 - val_accuracy: 0.9563
# Epoch 4/50
# 30/31 [============================>.] - ETA: 0s - loss: 0.2241 - accuracy: 0.9380
# Epoch 4: val_loss improved from 0.18703 to 0.16958, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 58ms/step - loss: 0.2212 - accuracy: 0.9401 - val_loss: 0.1696 - val_accuracy: 0.9625
# Epoch 5/50
# 31/31 [==============================] - ETA: 0s - loss: 0.1640 - accuracy: 0.9556
# Epoch 5: val_loss improved from 0.16958 to 0.08976, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 57ms/step - loss: 0.1640 - accuracy: 0.9556 - val_loss: 0.0898 - val_accuracy: 0.9750
# Epoch 6/50
# 31/31 [==============================] - ETA: 0s - loss: 0.1588 - accuracy: 0.9535
# Epoch 6: val_loss improved from 0.08976 to 0.07779, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 61ms/step - loss: 0.1588 - accuracy: 0.9535 - val_loss: 0.0778 - val_accuracy: 0.9750
# Epoch 7/50
# 31/31 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9638
# Epoch 7: val_loss improved from 0.07779 to 0.05504, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 61ms/step - loss: 0.1361 - accuracy: 0.9638 - val_loss: 0.0550 - val_accuracy: 1.0000
# Epoch 8/50
# 30/31 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9635
# Epoch 8: val_loss improved from 0.05504 to 0.04756, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 65ms/step - loss: 0.1173 - accuracy: 0.9638 - val_loss: 0.0476 - val_accuracy: 0.9937
# Epoch 9/50
# 31/31 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9690
# Epoch 9: val_loss improved from 0.04756 to 0.04683, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 65ms/step - loss: 0.1284 - accuracy: 0.9690 - val_loss: 0.0468 - val_accuracy: 0.9937
# Epoch 10/50
# 31/31 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9669
# Epoch 10: val_loss did not improve from 0.04683
# 31/31 [==============================] - 2s 64ms/step - loss: 0.1112 - accuracy: 0.9669 - val_loss: 0.0489 - val_accuracy: 0.9625
# Epoch 11/50
# 31/31 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9731
# Epoch 11: val_loss improved from 0.04683 to 0.03082, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 62ms/step - loss: 0.1169 - accuracy: 0.9731 - val_loss: 0.0308 - val_accuracy: 0.9937
# Epoch 12/50
# 31/31 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9649
# Epoch 12: val_loss did not improve from 0.03082
# 31/31 [==============================] - 2s 57ms/step - loss: 0.1142 - accuracy: 0.9649 - val_loss: 0.0372 - val_accuracy: 0.9937
# Epoch 13/50
# 30/31 [============================>.] - ETA: 0s - loss: 0.1066 - accuracy: 0.9679
# Epoch 13: val_loss improved from 0.03082 to 0.02194, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 62ms/step - loss: 0.1037 - accuracy: 0.9690 - val_loss: 0.0219 - val_accuracy: 0.9937
# Epoch 14/50
# 30/31 [============================>.] - ETA: 0s - loss: 0.0966 - accuracy: 0.9722
# Epoch 14: val_loss did not improve from 0.02194
# 31/31 [==============================] - 2s 57ms/step - loss: 0.0985 - accuracy: 0.9711 - val_loss: 0.0313 - val_accuracy: 0.9937
# Epoch 15/50
# 31/31 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9659
# Epoch 15: val_loss improved from 0.02194 to 0.02080, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 67ms/step - loss: 0.1122 - accuracy: 0.9659 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 16/50
# 31/31 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9752
# Epoch 16: val_loss did not improve from 0.02080
# 31/31 [==============================] - 2s 56ms/step - loss: 0.0976 - accuracy: 0.9752 - val_loss: 0.0219 - val_accuracy: 0.9937
# Epoch 17/50
# 31/31 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9698
# Epoch 17: val_loss improved from 0.02080 to 0.01950, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 57ms/step - loss: 0.0972 - accuracy: 0.9698 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 18/50
# 31/31 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9700
# Epoch 18: val_loss did not improve from 0.01950
# 31/31 [==============================] - 2s 56ms/step - loss: 0.0862 - accuracy: 0.9700 - val_loss: 0.0201 - val_accuracy: 0.9937
# Epoch 19/50
# 31/31 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9731
# Epoch 19: val_loss improved from 0.01950 to 0.01503, saving model to best_model_C12.h5
# 31/31 [==============================] - 2s 53ms/step - loss: 0.0795 - accuracy: 0.9731 - val_loss: 0.0150 - val_accuracy: 0.9937
# Epoch 20/50
# 30/31 [============================>.] - ETA: 0s - loss: 0.0746 - accuracy: 0.9765
# Epoch 20: val_loss did not improve from 0.01503
# 31/31 [==============================] - 2s 53ms/step - loss: 0.0733 - accuracy: 0.9773 - val_loss: 0.0156 - val_accuracy: 0.9937
# Epoch 21/50
# 31/31 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9700
# Epoch 21: val_loss did not improve from 0.01503
# 31/31 [==============================] - 2s 65ms/step - loss: 0.0933 - accuracy: 0.9700 - val_loss: 0.0188 - val_accuracy: 0.9937
# Epoch 22/50
# 31/31 [==============================] - ETA: 0s - loss: 0.0691 - accuracy: 0.9773
# Epoch 22: val_loss did not improve from 0.01503
# 31/31 [==============================] - 2s 61ms/step - loss: 0.0691 - accuracy: 0.9773 - val_loss: 0.0157 - val_accuracy: 0.9937
# Epoch 23/50
# 31/31 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9752
# Epoch 23: val_loss did not improve from 0.01503
# 31/31 [==============================] - 2s 60ms/step - loss: 0.0701 - accuracy: 0.9752 - val_loss: 0.0211 - val_accuracy: 0.9937
# Epoch 24/50
# 30/31 [============================>.] - ETA: 0s - loss: 0.0705 - accuracy: 0.9754
# Epoch 24: val_loss did not improve from 0.01503
# 31/31 [==============================] - 2s 56ms/step - loss: 0.0703 - accuracy: 0.9752 - val_loss: 0.0244 - val_accuracy: 0.9937
# Epoch 24: early stopping
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0358 - accuracy: 0.9881
# Test Loss: 0.035832569003105164
# Test Accuracy: 0.988095223903656

# %%
# Graficar precisión y pérdida
plt.figure(figsize=(12, 5))

# Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Línea para Test
plt.title('Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.text(len(history.history['accuracy']) - 1, test_accuracy, f'Test Accuracy: {test_accuracy:.2f}', color='r', ha='center')


# Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')  # Línea para Test
plt.title('Cross Entropy Loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.text(len(history.history['loss']) - 1, test_loss, f'Test Loss: {test_loss:.2f}', color='r', ha='center')

plt.show()
