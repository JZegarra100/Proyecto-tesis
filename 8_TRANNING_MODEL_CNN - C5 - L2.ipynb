# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt

# %%
# Directorios de entrenamiento, validación y prueba
train_dir = r'D:\Python\TESIS\CLUSTERS_C5_CALC_K\train'
val_dir = r'D:\Python\TESIS\CLUSTERS_C5_CALC_K\val'
test_dir = r'D:\Python\TESIS\CLUSTERS_C5_CALC_K\test'

# %%
# Configurar TensorFlow para que use solo la GPU 0 y optimizar el uso de la memoria
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU configurada correctamente.")
    except RuntimeError as e:
        print(e)

# Parámetros de la red y del entrenamiento
img_width, img_height = 170, 170  # Ajustado al lienzo de 170x170 píxeles
batch_size = 32
epochs = 50
num_classes = 1  # Número de categorías
# Out:
# GPU configurada correctamente.

# %%
# Generadores de datos para la carga y preprocesamiento de imágenes en escala de grises
train_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Generadores para train, val y test
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)  # No se necesita barajar para evaluar

# Construcción de la red neuronal convolucional
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# Configuración del modelo de entrenamiento
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=1e-4),
              metrics=['accuracy'])

# Callbacks para guardar el mejor modelo y detener temprano
checkpoint = ModelCheckpoint('best_model.h5', verbose=1, save_best_only=True, monitor='val_loss', mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

# Entrenamiento del modelo
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[checkpoint, early_stopping],
    workers=tf.data.experimental.AUTOTUNE,
    use_multiprocessing=True)

# Evaluación del modelo en el conjunto de prueba
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Found 500 images belonging to 1 classes.
# Found 22 images belonging to 1 classes.
# Found 12 images belonging to 1 classes.
# Epoch 1/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 4s 74ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 2/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 3/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 4/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 5/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 6/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 7/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 8/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 9/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 10/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 11/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 12/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 13/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 14/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 15/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 62ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 16/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 61ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 17/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 18/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 19/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 20/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 21/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 22/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 66ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 23/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 24/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 60ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 25/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 26/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 27/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 28/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 29/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 30/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 31/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 32/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 33/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 34/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 35/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 36/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 37/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 38/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 39/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 40/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 41/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 42/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 43/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 44/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 45/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 46/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 62ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 47/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 48/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 49/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 50/50
# 15/15 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Test Loss: 0.0
# Test Accuracy: 1.0

# %%
# Graficar precisión y pérdida
plt.figure(figsize=(12, 5))

# Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Línea para Test
plt.title('Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.text(len(history.history['accuracy']) - 1, test_accuracy, f'Test Accuracy: {test_accuracy:.2f}', color='r', ha='center')


# Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')  # Línea para Test
plt.title('Cross Entropy Loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.text(len(history.history['loss']) - 1, test_loss, f'Test Loss: {test_loss:.2f}', color='r', ha='center')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 7
#       5 plt.subplot(1, 2, 1)
#       6 plt.plot(history.history['accuracy'], label='Training Accuracy')
# ----> 7 plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
#       8 plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Línea para Test
#       9 plt.title('Accuracy vs Epochs')
#
# KeyError: 'val_accuracy'
