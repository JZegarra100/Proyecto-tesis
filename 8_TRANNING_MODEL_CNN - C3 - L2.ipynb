# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import SGD

# %%
# Directorios de entrenamiento, validación y prueba TAMBIEN MODIFICAR NUM_CLASS Y BEST_MODEL 
train_dir = r'D:\Python\TESIS\CLUSTERS_C3_CALC_K\train'
val_dir = r'D:\Python\TESIS\CLUSTERS_C3_CALC_K\val'
test_dir = r'D:\Python\TESIS\CLUSTERS_C3_CALC_K\test'

# %%
# Configurar TensorFlow para que use solo la GPU 0 y optimizar el uso de la memoria
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU configurada correctamente.")
    except RuntimeError as e:
        print(e)

# Parámetros de la red y del entrenamiento
img_width, img_height = 170, 170  # Ajustado al lienzo de 170x170 píxeles
batch_size = 64
epochs = 100
num_classes = 3  # Número de categorías
l2 = 0.02 

# Generadores de datos para la carga y preprocesamiento de imágenes en escala de grises
train_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Generadores para train, val y test
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)  # No se necesita barajar para evaluar
# Out:
# GPU configurada correctamente.
# Found 447 images belonging to 3 classes.
# Found 85 images belonging to 3 classes.
# Found 46 images belonging to 3 classes.

# %%
# Crear el modelo
model = Sequential()

# Primera capa convolucional con regularización L2
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 1), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Segunda capa convolucional con regularización L2
model.add(Conv2D(32, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Tercera capa convolucional con regularización L2
model.add(Conv2D(64, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))

# Cuarta capa convolucional con regularización L2
model.add(Conv2D(64, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Aplanar las capas convolucionales para conectarlas con capas densas
model.add(Flatten())

# Capa densa con regularización L2 y Dropout
model.add(Dense(128, kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Capa de salida
model.add(Dense(num_classes, kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('softmax'))

# Compilar el modelo con el optimizador SGD, una tasa de aprendizaje inicial baja y decaimiento
#optimizer = SGD(learning_rate=1e-4, momentum=0.9, decay=1e-6)
optimizer=Adam(learning_rate=1e-4)

# Configuración del modelo de entrenamiento
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Callbacks para guardar el mejor modelo y detener temprano
checkpoint = ModelCheckpoint('best_model_C3.h5', verbose=1, save_best_only=True, monitor='val_loss', mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

# Entrenamiento del modelo
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[checkpoint, early_stopping],
    workers=tf.data.experimental.AUTOTUNE,
    use_multiprocessing=True)

# Evaluación del modelo en el conjunto de prueba
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# 6/6 [==============================] - ETA: 0s - loss: 16.6691 - accuracy: 0.2977
# Epoch 1: val_loss improved from inf to 16.00026, saving model to best_model_C3.h5
# 6/6 [==============================] - 2s 171ms/step - loss: 16.6691 - accuracy: 0.2977 - val_loss: 16.0003 - val_accuracy: 0.5312
# Epoch 2/100
# 6/6 [==============================] - ETA: 0s - loss: 15.6007 - accuracy: 0.3420
# Epoch 2: val_loss improved from 16.00026 to 15.03251, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 15.6007 - accuracy: 0.3420 - val_loss: 15.0325 - val_accuracy: 0.3906
# Epoch 3/100
# 6/6 [==============================] - ETA: 0s - loss: 14.6115 - accuracy: 0.3125
# Epoch 3: val_loss improved from 15.03251 to 14.06578, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 14.6115 - accuracy: 0.3125 - val_loss: 14.0658 - val_accuracy: 0.2031
# Epoch 4/100
# 6/6 [==============================] - ETA: 0s - loss: 13.6726 - accuracy: 0.3446
# Epoch 4: val_loss improved from 14.06578 to 13.16825, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 150ms/step - loss: 13.6726 - accuracy: 0.3446 - val_loss: 13.1683 - val_accuracy: 0.2500
# Epoch 5/100
# 6/6 [==============================] - ETA: 0s - loss: 12.8122 - accuracy: 0.3760
# Epoch 5: val_loss improved from 13.16825 to 12.33740, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 12.8122 - accuracy: 0.3760 - val_loss: 12.3374 - val_accuracy: 0.2969
# Epoch 6/100
# 6/6 [==============================] - ETA: 0s - loss: 12.0167 - accuracy: 0.4360
# Epoch 6: val_loss improved from 12.33740 to 11.58640, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 144ms/step - loss: 12.0167 - accuracy: 0.4360 - val_loss: 11.5864 - val_accuracy: 0.3438
# Epoch 7/100
# 6/6 [==============================] - ETA: 0s - loss: 11.2910 - accuracy: 0.4308
# Epoch 7: val_loss improved from 11.58640 to 10.90378, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 11.2910 - accuracy: 0.4308 - val_loss: 10.9038 - val_accuracy: 0.4531
# Epoch 8/100
# 6/6 [==============================] - ETA: 0s - loss: 10.6265 - accuracy: 0.4073
# Epoch 8: val_loss improved from 10.90378 to 10.27478, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 10.6265 - accuracy: 0.4073 - val_loss: 10.2748 - val_accuracy: 0.2812
# Epoch 9/100
# 6/6 [==============================] - ETA: 0s - loss: 10.0182 - accuracy: 0.4073
# Epoch 9: val_loss improved from 10.27478 to 9.69529, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 10.0182 - accuracy: 0.4073 - val_loss: 9.6953 - val_accuracy: 0.5938
# Epoch 10/100
# 6/6 [==============================] - ETA: 0s - loss: 9.4681 - accuracy: 0.4465
# Epoch 10: val_loss improved from 9.69529 to 9.16728, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 9.4681 - accuracy: 0.4465 - val_loss: 9.1673 - val_accuracy: 0.7344
# Epoch 11/100
# 6/6 [==============================] - ETA: 0s - loss: 8.9577 - accuracy: 0.5130
# Epoch 11: val_loss improved from 9.16728 to 8.69005, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 143ms/step - loss: 8.9577 - accuracy: 0.5130 - val_loss: 8.6900 - val_accuracy: 0.4688
# Epoch 12/100
# 6/6 [==============================] - ETA: 0s - loss: 8.4987 - accuracy: 0.4909
# Epoch 12: val_loss improved from 8.69005 to 8.25326, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 151ms/step - loss: 8.4987 - accuracy: 0.4909 - val_loss: 8.2533 - val_accuracy: 0.4844
# Epoch 13/100
# 6/6 [==============================] - ETA: 0s - loss: 8.0717 - accuracy: 0.5013
# Epoch 13: val_loss improved from 8.25326 to 7.84768, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 148ms/step - loss: 8.0717 - accuracy: 0.5013 - val_loss: 7.8477 - val_accuracy: 0.4375
# Epoch 14/100
# 6/6 [==============================] - ETA: 0s - loss: 7.6835 - accuracy: 0.5469
# Epoch 14: val_loss improved from 7.84768 to 7.49010, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 144ms/step - loss: 7.6835 - accuracy: 0.5469 - val_loss: 7.4901 - val_accuracy: 0.5000
# Epoch 15/100
# 6/6 [==============================] - ETA: 0s - loss: 7.3337 - accuracy: 0.5640
# Epoch 15: val_loss improved from 7.49010 to 7.15385, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 147ms/step - loss: 7.3337 - accuracy: 0.5640 - val_loss: 7.1539 - val_accuracy: 0.6562
# Epoch 16/100
# 6/6 [==============================] - ETA: 0s - loss: 7.0071 - accuracy: 0.5509
# Epoch 16: val_loss improved from 7.15385 to 6.83663, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 7.0071 - accuracy: 0.5509 - val_loss: 6.8366 - val_accuracy: 0.7656
# Epoch 17/100
# 6/6 [==============================] - ETA: 0s - loss: 6.7112 - accuracy: 0.6057
# Epoch 17: val_loss improved from 6.83663 to 6.55359, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 142ms/step - loss: 6.7112 - accuracy: 0.6057 - val_loss: 6.5536 - val_accuracy: 0.8125
# Epoch 18/100
# 6/6 [==============================] - ETA: 0s - loss: 6.4326 - accuracy: 0.6084
# Epoch 18: val_loss improved from 6.55359 to 6.30038, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 145ms/step - loss: 6.4326 - accuracy: 0.6084 - val_loss: 6.3004 - val_accuracy: 0.6719
# Epoch 19/100
# 6/6 [==============================] - ETA: 0s - loss: 6.1749 - accuracy: 0.6719
# Epoch 19: val_loss improved from 6.30038 to 6.06834, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 132ms/step - loss: 6.1749 - accuracy: 0.6719 - val_loss: 6.0683 - val_accuracy: 0.5469
# Epoch 20/100
# 6/6 [==============================] - ETA: 0s - loss: 5.9362 - accuracy: 0.6449
# Epoch 20: val_loss improved from 6.06834 to 5.84955, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 136ms/step - loss: 5.9362 - accuracy: 0.6449 - val_loss: 5.8495 - val_accuracy: 0.6719
# Epoch 21/100
# 6/6 [==============================] - ETA: 0s - loss: 5.7268 - accuracy: 0.6397
# Epoch 21: val_loss improved from 5.84955 to 5.61295, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 5.7268 - accuracy: 0.6397 - val_loss: 5.6130 - val_accuracy: 0.8281
# Epoch 22/100
# 6/6 [==============================] - ETA: 0s - loss: 5.5051 - accuracy: 0.7050
# Epoch 22: val_loss improved from 5.61295 to 5.39409, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 5.5051 - accuracy: 0.7050 - val_loss: 5.3941 - val_accuracy: 0.9219
# Epoch 23/100
# 6/6 [==============================] - ETA: 0s - loss: 5.3095 - accuracy: 0.7031
# Epoch 23: val_loss improved from 5.39409 to 5.22572, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 142ms/step - loss: 5.3095 - accuracy: 0.7031 - val_loss: 5.2257 - val_accuracy: 0.8594
# Epoch 24/100
# 6/6 [==============================] - ETA: 0s - loss: 5.1067 - accuracy: 0.7493
# Epoch 24: val_loss improved from 5.22572 to 5.02670, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 131ms/step - loss: 5.1067 - accuracy: 0.7493 - val_loss: 5.0267 - val_accuracy: 0.8281
# Epoch 25/100
# 6/6 [==============================] - ETA: 0s - loss: 4.9249 - accuracy: 0.7441
# Epoch 25: val_loss improved from 5.02670 to 4.85675, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 4.9249 - accuracy: 0.7441 - val_loss: 4.8567 - val_accuracy: 0.7812
# Epoch 26/100
# 6/6 [==============================] - ETA: 0s - loss: 4.7258 - accuracy: 0.7676
# Epoch 26: val_loss improved from 4.85675 to 4.66049, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 143ms/step - loss: 4.7258 - accuracy: 0.7676 - val_loss: 4.6605 - val_accuracy: 0.8281
# Epoch 27/100
# 6/6 [==============================] - ETA: 0s - loss: 4.5618 - accuracy: 0.8094
# Epoch 27: val_loss improved from 4.66049 to 4.44564, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 4.5618 - accuracy: 0.8094 - val_loss: 4.4456 - val_accuracy: 0.8906
# Epoch 28/100
# 6/6 [==============================] - ETA: 0s - loss: 4.3831 - accuracy: 0.8146
# Epoch 28: val_loss improved from 4.44564 to 4.30265, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 4.3831 - accuracy: 0.8146 - val_loss: 4.3026 - val_accuracy: 0.9062
# Epoch 29/100
# 6/6 [==============================] - ETA: 0s - loss: 4.2255 - accuracy: 0.8381
# Epoch 29: val_loss improved from 4.30265 to 4.09330, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 151ms/step - loss: 4.2255 - accuracy: 0.8381 - val_loss: 4.0933 - val_accuracy: 0.9375
# Epoch 30/100
# 6/6 [==============================] - ETA: 0s - loss: 4.0725 - accuracy: 0.8721
# Epoch 30: val_loss improved from 4.09330 to 3.97913, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 153ms/step - loss: 4.0725 - accuracy: 0.8721 - val_loss: 3.9791 - val_accuracy: 0.9219
# Epoch 31/100
# 6/6 [==============================] - ETA: 0s - loss: 3.9792 - accuracy: 0.8721
# Epoch 31: val_loss improved from 3.97913 to 3.84783, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 3.9792 - accuracy: 0.8721 - val_loss: 3.8478 - val_accuracy: 0.9375
# Epoch 32/100
# 6/6 [==============================] - ETA: 0s - loss: 3.8136 - accuracy: 0.9138
# Epoch 32: val_loss improved from 3.84783 to 3.75011, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 3.8136 - accuracy: 0.9138 - val_loss: 3.7501 - val_accuracy: 0.9062
# Epoch 33/100
# 6/6 [==============================] - ETA: 0s - loss: 3.7448 - accuracy: 0.8851
# Epoch 33: val_loss improved from 3.75011 to 3.62070, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 146ms/step - loss: 3.7448 - accuracy: 0.8851 - val_loss: 3.6207 - val_accuracy: 0.9688
# Epoch 34/100
# 6/6 [==============================] - ETA: 0s - loss: 3.6277 - accuracy: 0.9034
# Epoch 34: val_loss improved from 3.62070 to 3.55416, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 3.6277 - accuracy: 0.9034 - val_loss: 3.5542 - val_accuracy: 0.9531
# Epoch 35/100
# 6/6 [==============================] - ETA: 0s - loss: 3.5388 - accuracy: 0.9089
# Epoch 35: val_loss improved from 3.55416 to 3.53261, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 128ms/step - loss: 3.5388 - accuracy: 0.9089 - val_loss: 3.5326 - val_accuracy: 0.9219
# Epoch 36/100
# 6/6 [==============================] - ETA: 0s - loss: 3.4433 - accuracy: 0.9323
# Epoch 36: val_loss improved from 3.53261 to 3.32029, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 3.4433 - accuracy: 0.9323 - val_loss: 3.3203 - val_accuracy: 0.9844
# Epoch 37/100
# 6/6 [==============================] - ETA: 0s - loss: 3.3665 - accuracy: 0.9217
# Epoch 37: val_loss did not improve from 3.32029
# 6/6 [==============================] - 1s 120ms/step - loss: 3.3665 - accuracy: 0.9217 - val_loss: 3.3393 - val_accuracy: 0.9219
# Epoch 38/100
# 6/6 [==============================] - ETA: 0s - loss: 3.3019 - accuracy: 0.9138
# Epoch 38: val_loss improved from 3.32029 to 3.21696, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 145ms/step - loss: 3.3019 - accuracy: 0.9138 - val_loss: 3.2170 - val_accuracy: 0.9844
# Epoch 39/100
# 6/6 [==============================] - ETA: 0s - loss: 3.2295 - accuracy: 0.9295
# Epoch 39: val_loss improved from 3.21696 to 3.16919, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 3.2295 - accuracy: 0.9295 - val_loss: 3.1692 - val_accuracy: 0.9688
# Epoch 40/100
# 6/6 [==============================] - ETA: 0s - loss: 3.1307 - accuracy: 0.9556
# Epoch 40: val_loss improved from 3.16919 to 3.08417, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 143ms/step - loss: 3.1307 - accuracy: 0.9556 - val_loss: 3.0842 - val_accuracy: 0.9844
# Epoch 41/100
# 6/6 [==============================] - ETA: 0s - loss: 3.0767 - accuracy: 0.9452
# Epoch 41: val_loss improved from 3.08417 to 3.05373, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 3.0767 - accuracy: 0.9452 - val_loss: 3.0537 - val_accuracy: 0.9375
# Epoch 42/100
# 6/6 [==============================] - ETA: 0s - loss: 2.9876 - accuracy: 0.9713
# Epoch 42: val_loss improved from 3.05373 to 2.94157, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 144ms/step - loss: 2.9876 - accuracy: 0.9713 - val_loss: 2.9416 - val_accuracy: 0.9844
# Epoch 43/100
# 6/6 [==============================] - ETA: 0s - loss: 2.9334 - accuracy: 0.9634
# Epoch 43: val_loss improved from 2.94157 to 2.88122, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 2.9334 - accuracy: 0.9634 - val_loss: 2.8812 - val_accuracy: 0.9844
# Epoch 44/100
# 6/6 [==============================] - ETA: 0s - loss: 2.8819 - accuracy: 0.9634
# Epoch 44: val_loss improved from 2.88122 to 2.85023, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 149ms/step - loss: 2.8819 - accuracy: 0.9634 - val_loss: 2.8502 - val_accuracy: 0.9844
# Epoch 45/100
# 6/6 [==============================] - ETA: 0s - loss: 2.8282 - accuracy: 0.9634
# Epoch 45: val_loss did not improve from 2.85023
# 6/6 [==============================] - 1s 117ms/step - loss: 2.8282 - accuracy: 0.9634 - val_loss: 2.8630 - val_accuracy: 0.9375
# Epoch 46/100
# 6/6 [==============================] - ETA: 0s - loss: 2.7858 - accuracy: 0.9556
# Epoch 46: val_loss improved from 2.85023 to 2.75468, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 146ms/step - loss: 2.7858 - accuracy: 0.9556 - val_loss: 2.7547 - val_accuracy: 0.9844
# Epoch 47/100
# 6/6 [==============================] - ETA: 0s - loss: 2.7164 - accuracy: 0.9739
# Epoch 47: val_loss did not improve from 2.75468
# 6/6 [==============================] - 1s 113ms/step - loss: 2.7164 - accuracy: 0.9739 - val_loss: 2.7560 - val_accuracy: 0.9375
# Epoch 48/100
# 6/6 [==============================] - ETA: 0s - loss: 2.6746 - accuracy: 0.9713
# Epoch 48: val_loss improved from 2.75468 to 2.64791, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 2.6746 - accuracy: 0.9713 - val_loss: 2.6479 - val_accuracy: 0.9688
# Epoch 49/100
# 6/6 [==============================] - ETA: 0s - loss: 2.6187 - accuracy: 0.9687
# Epoch 49: val_loss improved from 2.64791 to 2.62331, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 2.6187 - accuracy: 0.9687 - val_loss: 2.6233 - val_accuracy: 0.9688
# Epoch 50/100
# 6/6 [==============================] - ETA: 0s - loss: 2.5753 - accuracy: 0.9634
# Epoch 50: val_loss improved from 2.62331 to 2.57091, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 2.5753 - accuracy: 0.9634 - val_loss: 2.5709 - val_accuracy: 0.9844
# Epoch 51/100
# 6/6 [==============================] - ETA: 0s - loss: 2.5468 - accuracy: 0.9687
# Epoch 51: val_loss improved from 2.57091 to 2.46670, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 150ms/step - loss: 2.5468 - accuracy: 0.9687 - val_loss: 2.4667 - val_accuracy: 1.0000
# Epoch 52/100
# 6/6 [==============================] - ETA: 0s - loss: 2.4753 - accuracy: 0.9739
# Epoch 52: val_loss did not improve from 2.46670
# 6/6 [==============================] - 1s 127ms/step - loss: 2.4753 - accuracy: 0.9739 - val_loss: 2.4885 - val_accuracy: 0.9688
# Epoch 53/100
# 6/6 [==============================] - ETA: 0s - loss: 2.4350 - accuracy: 0.9843
# Epoch 53: val_loss improved from 2.46670 to 2.39641, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 151ms/step - loss: 2.4350 - accuracy: 0.9843 - val_loss: 2.3964 - val_accuracy: 0.9844
# Epoch 54/100
# 6/6 [==============================] - ETA: 0s - loss: 2.4013 - accuracy: 0.9713
# Epoch 54: val_loss improved from 2.39641 to 2.39364, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 149ms/step - loss: 2.4013 - accuracy: 0.9713 - val_loss: 2.3936 - val_accuracy: 0.9688
# Epoch 55/100
# 6/6 [==============================] - ETA: 0s - loss: 2.3595 - accuracy: 0.9687
# Epoch 55: val_loss improved from 2.39364 to 2.34869, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 148ms/step - loss: 2.3595 - accuracy: 0.9687 - val_loss: 2.3487 - val_accuracy: 0.9844
# Epoch 56/100
# 6/6 [==============================] - ETA: 0s - loss: 2.3085 - accuracy: 0.9817
# Epoch 56: val_loss improved from 2.34869 to 2.30664, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 152ms/step - loss: 2.3085 - accuracy: 0.9817 - val_loss: 2.3066 - val_accuracy: 0.9844
# Epoch 57/100
# 6/6 [==============================] - ETA: 0s - loss: 2.2847 - accuracy: 0.9634
# Epoch 57: val_loss improved from 2.30664 to 2.27017, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 2.2847 - accuracy: 0.9634 - val_loss: 2.2702 - val_accuracy: 0.9844
# Epoch 58/100
# 6/6 [==============================] - ETA: 0s - loss: 2.2335 - accuracy: 0.9844
# Epoch 58: val_loss improved from 2.27017 to 2.19373, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 142ms/step - loss: 2.2335 - accuracy: 0.9844 - val_loss: 2.1937 - val_accuracy: 0.9844
# Epoch 59/100
# 6/6 [==============================] - ETA: 0s - loss: 2.1952 - accuracy: 0.9765
# Epoch 59: val_loss did not improve from 2.19373
# 6/6 [==============================] - 1s 117ms/step - loss: 2.1952 - accuracy: 0.9765 - val_loss: 2.2059 - val_accuracy: 0.9688
# Epoch 60/100
# 6/6 [==============================] - ETA: 0s - loss: 2.1689 - accuracy: 0.9739
# Epoch 60: val_loss improved from 2.19373 to 2.11201, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 133ms/step - loss: 2.1689 - accuracy: 0.9739 - val_loss: 2.1120 - val_accuracy: 1.0000
# Epoch 61/100
# 6/6 [==============================] - ETA: 0s - loss: 2.1440 - accuracy: 0.9740
# Epoch 61: val_loss did not improve from 2.11201
# 6/6 [==============================] - 1s 122ms/step - loss: 2.1440 - accuracy: 0.9740 - val_loss: 2.1996 - val_accuracy: 0.9219
# Epoch 62/100
# 6/6 [==============================] - ETA: 0s - loss: 2.0991 - accuracy: 0.9687
# Epoch 62: val_loss improved from 2.11201 to 2.06870, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 149ms/step - loss: 2.0991 - accuracy: 0.9687 - val_loss: 2.0687 - val_accuracy: 0.9844
# Epoch 63/100
# 6/6 [==============================] - ETA: 0s - loss: 2.0643 - accuracy: 0.9739
# Epoch 63: val_loss did not improve from 2.06870
# 6/6 [==============================] - 1s 136ms/step - loss: 2.0643 - accuracy: 0.9739 - val_loss: 2.0697 - val_accuracy: 0.9531
# Epoch 64/100
# 6/6 [==============================] - ETA: 0s - loss: 2.0204 - accuracy: 0.9765
# Epoch 64: val_loss improved from 2.06870 to 2.02511, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 154ms/step - loss: 2.0204 - accuracy: 0.9765 - val_loss: 2.0251 - val_accuracy: 0.9844
# Epoch 65/100
# 6/6 [==============================] - ETA: 0s - loss: 1.9990 - accuracy: 0.9687
# Epoch 65: val_loss did not improve from 2.02511
# 6/6 [==============================] - 1s 123ms/step - loss: 1.9990 - accuracy: 0.9687 - val_loss: 2.0313 - val_accuracy: 0.9531
# Epoch 66/100
# 6/6 [==============================] - ETA: 0s - loss: 1.9667 - accuracy: 0.9739
# Epoch 66: val_loss improved from 2.02511 to 1.95192, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 155ms/step - loss: 1.9667 - accuracy: 0.9739 - val_loss: 1.9519 - val_accuracy: 0.9844
# Epoch 67/100
# 6/6 [==============================] - ETA: 0s - loss: 1.9140 - accuracy: 0.9869
# Epoch 67: val_loss improved from 1.95192 to 1.92497, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 149ms/step - loss: 1.9140 - accuracy: 0.9869 - val_loss: 1.9250 - val_accuracy: 0.9688
# Epoch 68/100
# 6/6 [==============================] - ETA: 0s - loss: 1.8972 - accuracy: 0.9766
# Epoch 68: val_loss improved from 1.92497 to 1.89809, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 148ms/step - loss: 1.8972 - accuracy: 0.9766 - val_loss: 1.8981 - val_accuracy: 0.9844
# Epoch 69/100
# 6/6 [==============================] - ETA: 0s - loss: 1.8601 - accuracy: 0.9844
# Epoch 69: val_loss improved from 1.89809 to 1.86375, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 142ms/step - loss: 1.8601 - accuracy: 0.9844 - val_loss: 1.8637 - val_accuracy: 0.9844
# Epoch 70/100
# 6/6 [==============================] - ETA: 0s - loss: 1.8582 - accuracy: 0.9608
# Epoch 70: val_loss did not improve from 1.86375
# 6/6 [==============================] - 1s 120ms/step - loss: 1.8582 - accuracy: 0.9608 - val_loss: 1.8693 - val_accuracy: 0.9844
# Epoch 71/100
# 6/6 [==============================] - ETA: 0s - loss: 1.8137 - accuracy: 0.9817
# Epoch 71: val_loss improved from 1.86375 to 1.82491, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 138ms/step - loss: 1.8137 - accuracy: 0.9817 - val_loss: 1.8249 - val_accuracy: 0.9688
# Epoch 72/100
# 6/6 [==============================] - ETA: 0s - loss: 1.7859 - accuracy: 0.9765
# Epoch 72: val_loss improved from 1.82491 to 1.78130, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 129ms/step - loss: 1.7859 - accuracy: 0.9765 - val_loss: 1.7813 - val_accuracy: 0.9844
# Epoch 73/100
# 6/6 [==============================] - ETA: 0s - loss: 1.7691 - accuracy: 0.9739
# Epoch 73: val_loss did not improve from 1.78130
# 6/6 [==============================] - 1s 117ms/step - loss: 1.7691 - accuracy: 0.9739 - val_loss: 1.7883 - val_accuracy: 0.9688
# Epoch 74/100
# 6/6 [==============================] - ETA: 0s - loss: 1.7469 - accuracy: 0.9661
# Epoch 74: val_loss improved from 1.78130 to 1.69082, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 147ms/step - loss: 1.7469 - accuracy: 0.9661 - val_loss: 1.6908 - val_accuracy: 1.0000
# Epoch 75/100
# 6/6 [==============================] - ETA: 0s - loss: 1.7016 - accuracy: 0.9843
# Epoch 75: val_loss did not improve from 1.69082
# 6/6 [==============================] - 1s 121ms/step - loss: 1.7016 - accuracy: 0.9843 - val_loss: 1.7196 - val_accuracy: 0.9844
# Epoch 76/100
# 6/6 [==============================] - ETA: 0s - loss: 1.6780 - accuracy: 0.9791
# Epoch 76: val_loss improved from 1.69082 to 1.65568, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 148ms/step - loss: 1.6780 - accuracy: 0.9791 - val_loss: 1.6557 - val_accuracy: 0.9844
# Epoch 77/100
# 6/6 [==============================] - ETA: 0s - loss: 1.6484 - accuracy: 0.9870
# Epoch 77: val_loss improved from 1.65568 to 1.61879, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 147ms/step - loss: 1.6484 - accuracy: 0.9870 - val_loss: 1.6188 - val_accuracy: 1.0000
# Epoch 78/100
# 6/6 [==============================] - ETA: 0s - loss: 1.6193 - accuracy: 0.9870
# Epoch 78: val_loss improved from 1.61879 to 1.59258, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 1.6193 - accuracy: 0.9870 - val_loss: 1.5926 - val_accuracy: 1.0000
# Epoch 79/100
# 6/6 [==============================] - ETA: 0s - loss: 1.6030 - accuracy: 0.9843
# Epoch 79: val_loss improved from 1.59258 to 1.55308, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 134ms/step - loss: 1.6030 - accuracy: 0.9843 - val_loss: 1.5531 - val_accuracy: 1.0000
# Epoch 80/100
# 6/6 [==============================] - ETA: 0s - loss: 1.5787 - accuracy: 0.9843
# Epoch 80: val_loss did not improve from 1.55308
# 6/6 [==============================] - 1s 121ms/step - loss: 1.5787 - accuracy: 0.9843 - val_loss: 1.5654 - val_accuracy: 0.9844
# Epoch 81/100
# 6/6 [==============================] - ETA: 0s - loss: 1.5596 - accuracy: 0.9817
# Epoch 81: val_loss improved from 1.55308 to 1.54829, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 145ms/step - loss: 1.5596 - accuracy: 0.9817 - val_loss: 1.5483 - val_accuracy: 0.9844
# Epoch 82/100
# 6/6 [==============================] - ETA: 0s - loss: 1.5313 - accuracy: 0.9817
# Epoch 82: val_loss improved from 1.54829 to 1.53187, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 1.5313 - accuracy: 0.9817 - val_loss: 1.5319 - val_accuracy: 0.9688
# Epoch 83/100
# 6/6 [==============================] - ETA: 0s - loss: 1.5121 - accuracy: 0.9869
# Epoch 83: val_loss improved from 1.53187 to 1.51757, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 1.5121 - accuracy: 0.9869 - val_loss: 1.5176 - val_accuracy: 0.9844
# Epoch 84/100
# 6/6 [==============================] - ETA: 0s - loss: 1.4843 - accuracy: 0.9896
# Epoch 84: val_loss improved from 1.51757 to 1.51371, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 137ms/step - loss: 1.4843 - accuracy: 0.9896 - val_loss: 1.5137 - val_accuracy: 0.9844
# Epoch 85/100
# 6/6 [==============================] - ETA: 0s - loss: 1.4499 - accuracy: 0.9922
# Epoch 85: val_loss improved from 1.51371 to 1.45679, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 149ms/step - loss: 1.4499 - accuracy: 0.9922 - val_loss: 1.4568 - val_accuracy: 0.9844
# Epoch 86/100
# 6/6 [==============================] - ETA: 0s - loss: 1.4416 - accuracy: 0.9869
# Epoch 86: val_loss did not improve from 1.45679
# 6/6 [==============================] - 1s 117ms/step - loss: 1.4416 - accuracy: 0.9869 - val_loss: 1.4626 - val_accuracy: 0.9844
# Epoch 87/100
# 6/6 [==============================] - ETA: 0s - loss: 1.4200 - accuracy: 0.9843
# Epoch 87: val_loss improved from 1.45679 to 1.40059, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 1.4200 - accuracy: 0.9843 - val_loss: 1.4006 - val_accuracy: 1.0000
# Epoch 88/100
# 6/6 [==============================] - ETA: 0s - loss: 1.4037 - accuracy: 0.9713
# Epoch 88: val_loss did not improve from 1.40059
# 6/6 [==============================] - 1s 124ms/step - loss: 1.4037 - accuracy: 0.9713 - val_loss: 1.4177 - val_accuracy: 0.9844
# Epoch 89/100
# 6/6 [==============================] - ETA: 0s - loss: 1.3883 - accuracy: 0.9869
# Epoch 89: val_loss improved from 1.40059 to 1.39197, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 145ms/step - loss: 1.3883 - accuracy: 0.9869 - val_loss: 1.3920 - val_accuracy: 0.9844
# Epoch 90/100
# 6/6 [==============================] - ETA: 0s - loss: 1.3659 - accuracy: 0.9843
# Epoch 90: val_loss improved from 1.39197 to 1.34927, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 126ms/step - loss: 1.3659 - accuracy: 0.9843 - val_loss: 1.3493 - val_accuracy: 1.0000
# Epoch 91/100
# 6/6 [==============================] - ETA: 0s - loss: 1.3488 - accuracy: 0.9791
# Epoch 91: val_loss did not improve from 1.34927
# 6/6 [==============================] - 1s 133ms/step - loss: 1.3488 - accuracy: 0.9791 - val_loss: 1.3789 - val_accuracy: 0.9688
# Epoch 92/100
# 6/6 [==============================] - ETA: 0s - loss: 1.3210 - accuracy: 0.9818
# Epoch 92: val_loss improved from 1.34927 to 1.32274, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 139ms/step - loss: 1.3210 - accuracy: 0.9818 - val_loss: 1.3227 - val_accuracy: 0.9688
# Epoch 93/100
# 6/6 [==============================] - ETA: 0s - loss: 1.3040 - accuracy: 0.9869
# Epoch 93: val_loss improved from 1.32274 to 1.30846, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 1.3040 - accuracy: 0.9869 - val_loss: 1.3085 - val_accuracy: 0.9844
# Epoch 94/100
# 6/6 [==============================] - ETA: 0s - loss: 1.2983 - accuracy: 0.9791
# Epoch 94: val_loss improved from 1.30846 to 1.28905, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 141ms/step - loss: 1.2983 - accuracy: 0.9791 - val_loss: 1.2890 - val_accuracy: 0.9844
# Epoch 95/100
# 6/6 [==============================] - ETA: 0s - loss: 1.2837 - accuracy: 0.9791
# Epoch 95: val_loss did not improve from 1.28905
# 6/6 [==============================] - 1s 115ms/step - loss: 1.2837 - accuracy: 0.9791 - val_loss: 1.2969 - val_accuracy: 0.9844
# Epoch 96/100
# 6/6 [==============================] - ETA: 0s - loss: 1.2643 - accuracy: 0.9843
# Epoch 96: val_loss improved from 1.28905 to 1.25456, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 130ms/step - loss: 1.2643 - accuracy: 0.9843 - val_loss: 1.2546 - val_accuracy: 1.0000
# Epoch 97/100
# 6/6 [==============================] - ETA: 0s - loss: 1.2306 - accuracy: 0.9870
# Epoch 97: val_loss improved from 1.25456 to 1.21118, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 135ms/step - loss: 1.2306 - accuracy: 0.9870 - val_loss: 1.2112 - val_accuracy: 1.0000
# Epoch 98/100
# 6/6 [==============================] - ETA: 0s - loss: 1.2141 - accuracy: 0.9896
# Epoch 98: val_loss did not improve from 1.21118
# 6/6 [==============================] - 1s 121ms/step - loss: 1.2141 - accuracy: 0.9896 - val_loss: 1.2312 - val_accuracy: 0.9688
# Epoch 99/100
# 6/6 [==============================] - ETA: 0s - loss: 1.2205 - accuracy: 0.9687
# Epoch 99: val_loss improved from 1.21118 to 1.18160, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 148ms/step - loss: 1.2205 - accuracy: 0.9687 - val_loss: 1.1816 - val_accuracy: 1.0000
# Epoch 100/100
# 6/6 [==============================] - ETA: 0s - loss: 1.1906 - accuracy: 0.9896
# Epoch 100: val_loss improved from 1.18160 to 1.16631, saving model to best_model_C3.h5
# 6/6 [==============================] - 1s 140ms/step - loss: 1.1906 - accuracy: 0.9896 - val_loss: 1.1663 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 124ms/step - loss: 1.1447 - accuracy: 1.0000
# Test Loss: 1.1446964740753174
# Test Accuracy: 1.0

# %%
# Graficar precisión y pérdida
plt.figure(figsize=(12, 5))

# Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Línea para Test
plt.title('Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.text(len(history.history['accuracy']) - 1, test_accuracy, f'Test Accuracy: {test_accuracy:.2f}', color='r', ha='center')


# Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')  # Línea para Test
plt.title('Cross Entropy Loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.text(len(history.history['loss']) - 1, test_loss, f'Test Loss: {test_loss:.2f}', color='r', ha='center')

plt.show()
