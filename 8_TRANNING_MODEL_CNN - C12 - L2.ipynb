# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import SGD

# %%
# Directorios de entrenamiento, validación y prueba TAMBIEN MODIFICAR NUM_CLASS Y BEST_MODEL 
train_dir = r'D:\Python\TESIS\CLUSTERS_C12_CALC_K\train'
val_dir = r'D:\Python\TESIS\CLUSTERS_C12_CALC_K\val'
test_dir = r'D:\Python\TESIS\CLUSTERS_C12_CALC_K\test'

# %%
# Configurar TensorFlow para que use solo la GPU 0 y optimizar el uso de la memoria
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU configurada correctamente.")
    except RuntimeError as e:
        print(e)

# Parámetros de la red y del entrenamiento
img_width, img_height = 170, 170  # Ajustado al lienzo de 170x170 píxeles
batch_size = 64
epochs = 100
num_classes = 2  # Número de categorías
l2 = 0.02 

# Generadores de datos para la carga y preprocesamiento de imágenes en escala de grises
train_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Generadores para train, val y test
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)  # No se necesita barajar para evaluar
# Out:
# GPU configurada correctamente.
# Found 1000 images belonging to 2 classes.
# Found 165 images belonging to 2 classes.
# Found 84 images belonging to 2 classes.

# %%
# Crear el modelo
model = Sequential()

# Primera capa convolucional con regularización L2
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 1), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Segunda capa convolucional con regularización L2
model.add(Conv2D(32, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Tercera capa convolucional con regularización L2
model.add(Conv2D(64, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))

# Cuarta capa convolucional con regularización L2
model.add(Conv2D(64, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Aplanar las capas convolucionales para conectarlas con capas densas
model.add(Flatten())

# Capa densa con regularización L2 y Dropout
model.add(Dense(128, kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Capa de salida
model.add(Dense(num_classes, kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('softmax'))

# Compilar el modelo con el optimizador SGD, una tasa de aprendizaje inicial baja y decaimiento
#optimizer = SGD(learning_rate=1e-4, momentum=0.9, decay=1e-6)
optimizer=Adam(learning_rate=1e-4)

# Configuración del modelo de entrenamiento
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Callbacks para guardar el mejor modelo y detener temprano
checkpoint = ModelCheckpoint('best_model_C12.h5', verbose=1, save_best_only=True, monitor='val_loss', mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

# Entrenamiento del modelo
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[checkpoint, early_stopping],
    workers=tf.data.experimental.AUTOTUNE,
    use_multiprocessing=True)

# Evaluación del modelo en el conjunto de prueba
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# 15/15 [==============================] - ETA: 0s - loss: 8.0730 - accuracy: 0.6100
# Epoch 1: val_loss improved from inf to 7.43387, saving model to best_model_C12.h5
# 15/15 [==============================] - 6s 169ms/step - loss: 8.0730 - accuracy: 0.6100 - val_loss: 7.4339 - val_accuracy: 0.9219
# Epoch 2/100
# 15/15 [==============================] - ETA: 0s - loss: 6.9248 - accuracy: 0.6891
# Epoch 2: val_loss improved from 7.43387 to 6.40151, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 115ms/step - loss: 6.9248 - accuracy: 0.6891 - val_loss: 6.4015 - val_accuracy: 0.9453
# Epoch 3/100
# 15/15 [==============================] - ETA: 0s - loss: 5.9245 - accuracy: 0.8793
# Epoch 3: val_loss improved from 6.40151 to 5.46967, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 110ms/step - loss: 5.9245 - accuracy: 0.8793 - val_loss: 5.4697 - val_accuracy: 0.9141
# Epoch 4/100
# 15/15 [==============================] - ETA: 0s - loss: 5.1253 - accuracy: 0.8921
# Epoch 4: val_loss improved from 5.46967 to 4.70968, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 109ms/step - loss: 5.1253 - accuracy: 0.8921 - val_loss: 4.7097 - val_accuracy: 0.8984
# Epoch 5/100
# 15/15 [==============================] - ETA: 0s - loss: 4.4327 - accuracy: 0.9252
# Epoch 5: val_loss improved from 4.70968 to 4.11524, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 101ms/step - loss: 4.4327 - accuracy: 0.9252 - val_loss: 4.1152 - val_accuracy: 0.9688
# Epoch 6/100
# 15/15 [==============================] - ETA: 0s - loss: 3.8967 - accuracy: 0.9434
# Epoch 6: val_loss improved from 4.11524 to 3.63399, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 117ms/step - loss: 3.8967 - accuracy: 0.9434 - val_loss: 3.6340 - val_accuracy: 0.9453
# Epoch 7/100
# 15/15 [==============================] - ETA: 0s - loss: 3.4893 - accuracy: 0.9402
# Epoch 7: val_loss improved from 3.63399 to 3.27544, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 110ms/step - loss: 3.4893 - accuracy: 0.9402 - val_loss: 3.2754 - val_accuracy: 0.9531
# Epoch 8/100
# 15/15 [==============================] - ETA: 0s - loss: 3.1659 - accuracy: 0.9466
# Epoch 8: val_loss improved from 3.27544 to 2.99877, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 110ms/step - loss: 3.1659 - accuracy: 0.9466 - val_loss: 2.9988 - val_accuracy: 0.9609
# Epoch 9/100
# 15/15 [==============================] - ETA: 0s - loss: 2.9021 - accuracy: 0.9509
# Epoch 9: val_loss improved from 2.99877 to 2.74149, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 107ms/step - loss: 2.9021 - accuracy: 0.9509 - val_loss: 2.7415 - val_accuracy: 0.9609
# Epoch 10/100
# 15/15 [==============================] - ETA: 0s - loss: 2.7046 - accuracy: 0.9487
# Epoch 10: val_loss improved from 2.74149 to 2.55064, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 112ms/step - loss: 2.7046 - accuracy: 0.9487 - val_loss: 2.5506 - val_accuracy: 0.9688
# Epoch 11/100
# 15/15 [==============================] - ETA: 0s - loss: 2.5098 - accuracy: 0.9594
# Epoch 11: val_loss improved from 2.55064 to 2.42047, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 108ms/step - loss: 2.5098 - accuracy: 0.9594 - val_loss: 2.4205 - val_accuracy: 0.9688
# Epoch 12/100
# 15/15 [==============================] - ETA: 0s - loss: 2.3594 - accuracy: 0.9594
# Epoch 12: val_loss improved from 2.42047 to 2.27076, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 115ms/step - loss: 2.3594 - accuracy: 0.9594 - val_loss: 2.2708 - val_accuracy: 0.9844
# Epoch 13/100
# 15/15 [==============================] - ETA: 0s - loss: 2.2381 - accuracy: 0.9605
# Epoch 13: val_loss improved from 2.27076 to 2.12037, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 113ms/step - loss: 2.2381 - accuracy: 0.9605 - val_loss: 2.1204 - val_accuracy: 0.9922
# Epoch 14/100
# 15/15 [==============================] - ETA: 0s - loss: 2.1084 - accuracy: 0.9669
# Epoch 14: val_loss improved from 2.12037 to 2.00659, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 111ms/step - loss: 2.1084 - accuracy: 0.9669 - val_loss: 2.0066 - val_accuracy: 0.9766
# Epoch 15/100
# 15/15 [==============================] - ETA: 0s - loss: 2.0263 - accuracy: 0.9541
# Epoch 15: val_loss improved from 2.00659 to 1.91347, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 114ms/step - loss: 2.0263 - accuracy: 0.9541 - val_loss: 1.9135 - val_accuracy: 0.9766
# Epoch 16/100
# 15/15 [==============================] - ETA: 0s - loss: 1.9211 - accuracy: 0.9669
# Epoch 16: val_loss improved from 1.91347 to 1.81957, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 108ms/step - loss: 1.9211 - accuracy: 0.9669 - val_loss: 1.8196 - val_accuracy: 0.9922
# Epoch 17/100
# 15/15 [==============================] - ETA: 0s - loss: 1.8368 - accuracy: 0.9712
# Epoch 17: val_loss improved from 1.81957 to 1.76617, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 104ms/step - loss: 1.8368 - accuracy: 0.9712 - val_loss: 1.7662 - val_accuracy: 0.9922
# Epoch 18/100
# 15/15 [==============================] - ETA: 0s - loss: 1.7649 - accuracy: 0.9688
# Epoch 18: val_loss improved from 1.76617 to 1.67121, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 108ms/step - loss: 1.7649 - accuracy: 0.9688 - val_loss: 1.6712 - val_accuracy: 1.0000
# Epoch 19/100
# 15/15 [==============================] - ETA: 0s - loss: 1.7016 - accuracy: 0.9637
# Epoch 19: val_loss improved from 1.67121 to 1.62014, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 104ms/step - loss: 1.7016 - accuracy: 0.9637 - val_loss: 1.6201 - val_accuracy: 0.9922
# Epoch 20/100
# 15/15 [==============================] - ETA: 0s - loss: 1.6403 - accuracy: 0.9669
# Epoch 20: val_loss improved from 1.62014 to 1.56434, saving model to best_model_C12.h5
# 15/15 [==============================] - 1s 95ms/step - loss: 1.6403 - accuracy: 0.9669 - val_loss: 1.5643 - val_accuracy: 0.9922
# Epoch 21/100
# 15/15 [==============================] - ETA: 0s - loss: 1.5664 - accuracy: 0.9744
# Epoch 21: val_loss improved from 1.56434 to 1.48582, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 104ms/step - loss: 1.5664 - accuracy: 0.9744 - val_loss: 1.4858 - val_accuracy: 1.0000
# Epoch 22/100
# 15/15 [==============================] - ETA: 0s - loss: 1.5170 - accuracy: 0.9658
# Epoch 22: val_loss improved from 1.48582 to 1.43861, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 114ms/step - loss: 1.5170 - accuracy: 0.9658 - val_loss: 1.4386 - val_accuracy: 0.9922
# Epoch 23/100
# 15/15 [==============================] - ETA: 0s - loss: 1.4630 - accuracy: 0.9701
# Epoch 23: val_loss improved from 1.43861 to 1.38444, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 116ms/step - loss: 1.4630 - accuracy: 0.9701 - val_loss: 1.3844 - val_accuracy: 1.0000
# Epoch 24/100
# 15/15 [==============================] - ETA: 0s - loss: 1.4118 - accuracy: 0.9690
# Epoch 24: val_loss improved from 1.38444 to 1.35242, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 112ms/step - loss: 1.4118 - accuracy: 0.9690 - val_loss: 1.3524 - val_accuracy: 0.9922
# Epoch 25/100
# 15/15 [==============================] - ETA: 0s - loss: 1.3622 - accuracy: 0.9722
# Epoch 25: val_loss improved from 1.35242 to 1.28590, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 121ms/step - loss: 1.3622 - accuracy: 0.9722 - val_loss: 1.2859 - val_accuracy: 1.0000
# Epoch 26/100
# 15/15 [==============================] - ETA: 0s - loss: 1.3164 - accuracy: 0.9733
# Epoch 26: val_loss improved from 1.28590 to 1.23644, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 110ms/step - loss: 1.3164 - accuracy: 0.9733 - val_loss: 1.2364 - val_accuracy: 1.0000
# Epoch 27/100
# 15/15 [==============================] - ETA: 0s - loss: 1.2743 - accuracy: 0.9733
# Epoch 27: val_loss improved from 1.23644 to 1.20450, saving model to best_model_C12.h5
# 15/15 [==============================] - 1s 96ms/step - loss: 1.2743 - accuracy: 0.9733 - val_loss: 1.2045 - val_accuracy: 0.9922
# Epoch 28/100
# 15/15 [==============================] - ETA: 0s - loss: 1.2438 - accuracy: 0.9669
# Epoch 28: val_loss improved from 1.20450 to 1.16266, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 104ms/step - loss: 1.2438 - accuracy: 0.9669 - val_loss: 1.1627 - val_accuracy: 0.9922
# Epoch 29/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1904 - accuracy: 0.9733
# Epoch 29: val_loss improved from 1.16266 to 1.12467, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 113ms/step - loss: 1.1904 - accuracy: 0.9733 - val_loss: 1.1247 - val_accuracy: 0.9922
# Epoch 30/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1634 - accuracy: 0.9669
# Epoch 30: val_loss improved from 1.12467 to 1.07868, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 113ms/step - loss: 1.1634 - accuracy: 0.9669 - val_loss: 1.0787 - val_accuracy: 1.0000
# Epoch 31/100
# 15/15 [==============================] - ETA: 0s - loss: 1.1217 - accuracy: 0.9669
# Epoch 31: val_loss improved from 1.07868 to 1.04258, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 106ms/step - loss: 1.1217 - accuracy: 0.9669 - val_loss: 1.0426 - val_accuracy: 1.0000
# Epoch 32/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0895 - accuracy: 0.9722
# Epoch 32: val_loss improved from 1.04258 to 1.01761, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 108ms/step - loss: 1.0895 - accuracy: 0.9722 - val_loss: 1.0176 - val_accuracy: 1.0000
# Epoch 33/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0626 - accuracy: 0.9701
# Epoch 33: val_loss improved from 1.01761 to 0.98757, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 114ms/step - loss: 1.0626 - accuracy: 0.9701 - val_loss: 0.9876 - val_accuracy: 0.9922
# Epoch 34/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0249 - accuracy: 0.9701
# Epoch 34: val_loss improved from 0.98757 to 0.95931, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 115ms/step - loss: 1.0249 - accuracy: 0.9701 - val_loss: 0.9593 - val_accuracy: 1.0000
# Epoch 35/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0024 - accuracy: 0.9679
# Epoch 35: val_loss improved from 0.95931 to 0.95813, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 115ms/step - loss: 1.0024 - accuracy: 0.9679 - val_loss: 0.9581 - val_accuracy: 0.9922
# Epoch 36/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9689 - accuracy: 0.9744
# Epoch 36: val_loss improved from 0.95813 to 0.90335, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 115ms/step - loss: 0.9689 - accuracy: 0.9744 - val_loss: 0.9033 - val_accuracy: 1.0000
# Epoch 37/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9356 - accuracy: 0.9776
# Epoch 37: val_loss improved from 0.90335 to 0.89192, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 114ms/step - loss: 0.9356 - accuracy: 0.9776 - val_loss: 0.8919 - val_accuracy: 0.9922
# Epoch 38/100
# 15/15 [==============================] - ETA: 0s - loss: 0.9256 - accuracy: 0.9729
# Epoch 38: val_loss improved from 0.89192 to 0.85223, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 109ms/step - loss: 0.9256 - accuracy: 0.9729 - val_loss: 0.8522 - val_accuracy: 1.0000
# Epoch 39/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8937 - accuracy: 0.9719
# Epoch 39: val_loss improved from 0.85223 to 0.82827, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 105ms/step - loss: 0.8937 - accuracy: 0.9719 - val_loss: 0.8283 - val_accuracy: 1.0000
# Epoch 40/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8729 - accuracy: 0.9722
# Epoch 40: val_loss improved from 0.82827 to 0.80505, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 111ms/step - loss: 0.8729 - accuracy: 0.9722 - val_loss: 0.8051 - val_accuracy: 1.0000
# Epoch 41/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8511 - accuracy: 0.9776
# Epoch 41: val_loss improved from 0.80505 to 0.79998, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 106ms/step - loss: 0.8511 - accuracy: 0.9776 - val_loss: 0.8000 - val_accuracy: 0.9922
# Epoch 42/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8296 - accuracy: 0.9744
# Epoch 42: val_loss improved from 0.79998 to 0.76325, saving model to best_model_C12.h5
# 15/15 [==============================] - 1s 97ms/step - loss: 0.8296 - accuracy: 0.9744 - val_loss: 0.7633 - val_accuracy: 1.0000
# Epoch 43/100
# 15/15 [==============================] - ETA: 0s - loss: 0.8164 - accuracy: 0.9701
# Epoch 43: val_loss improved from 0.76325 to 0.75023, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 111ms/step - loss: 0.8164 - accuracy: 0.9701 - val_loss: 0.7502 - val_accuracy: 0.9922
# Epoch 44/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7928 - accuracy: 0.9679
# Epoch 44: val_loss improved from 0.75023 to 0.73645, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 105ms/step - loss: 0.7928 - accuracy: 0.9679 - val_loss: 0.7364 - val_accuracy: 0.9922
# Epoch 45/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7700 - accuracy: 0.9808
# Epoch 45: val_loss improved from 0.73645 to 0.71196, saving model to best_model_C12.h5
# 15/15 [==============================] - 1s 100ms/step - loss: 0.7700 - accuracy: 0.9808 - val_loss: 0.7120 - val_accuracy: 0.9922
# Epoch 46/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7616 - accuracy: 0.9750
# Epoch 46: val_loss did not improve from 0.71196
# 15/15 [==============================] - 2s 105ms/step - loss: 0.7616 - accuracy: 0.9750 - val_loss: 0.7232 - val_accuracy: 1.0000
# Epoch 47/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7519 - accuracy: 0.9733
# Epoch 47: val_loss improved from 0.71196 to 0.68203, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 111ms/step - loss: 0.7519 - accuracy: 0.9733 - val_loss: 0.6820 - val_accuracy: 1.0000
# Epoch 48/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7398 - accuracy: 0.9690
# Epoch 48: val_loss improved from 0.68203 to 0.66894, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 110ms/step - loss: 0.7398 - accuracy: 0.9690 - val_loss: 0.6689 - val_accuracy: 0.9922
# Epoch 49/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7251 - accuracy: 0.9690
# Epoch 49: val_loss improved from 0.66894 to 0.66167, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 123ms/step - loss: 0.7251 - accuracy: 0.9690 - val_loss: 0.6617 - val_accuracy: 1.0000
# Epoch 50/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6986 - accuracy: 0.9733
# Epoch 50: val_loss improved from 0.66167 to 0.64377, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 125ms/step - loss: 0.6986 - accuracy: 0.9733 - val_loss: 0.6438 - val_accuracy: 1.0000
# Epoch 51/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6898 - accuracy: 0.9760
# Epoch 51: val_loss improved from 0.64377 to 0.62225, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 103ms/step - loss: 0.6898 - accuracy: 0.9760 - val_loss: 0.6222 - val_accuracy: 1.0000
# Epoch 52/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6738 - accuracy: 0.9765
# Epoch 52: val_loss improved from 0.62225 to 0.61295, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 109ms/step - loss: 0.6738 - accuracy: 0.9765 - val_loss: 0.6130 - val_accuracy: 1.0000
# Epoch 53/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6577 - accuracy: 0.9760
# Epoch 53: val_loss improved from 0.61295 to 0.59707, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 108ms/step - loss: 0.6577 - accuracy: 0.9760 - val_loss: 0.5971 - val_accuracy: 1.0000
# Epoch 54/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6395 - accuracy: 0.9776
# Epoch 54: val_loss improved from 0.59707 to 0.59109, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 111ms/step - loss: 0.6395 - accuracy: 0.9776 - val_loss: 0.5911 - val_accuracy: 0.9922
# Epoch 55/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6439 - accuracy: 0.9701
# Epoch 55: val_loss improved from 0.59109 to 0.58482, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 102ms/step - loss: 0.6439 - accuracy: 0.9701 - val_loss: 0.5848 - val_accuracy: 0.9922
# Epoch 56/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6239 - accuracy: 0.9776
# Epoch 56: val_loss improved from 0.58482 to 0.56740, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 112ms/step - loss: 0.6239 - accuracy: 0.9776 - val_loss: 0.5674 - val_accuracy: 1.0000
# Epoch 57/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6093 - accuracy: 0.9754
# Epoch 57: val_loss improved from 0.56740 to 0.55319, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 108ms/step - loss: 0.6093 - accuracy: 0.9754 - val_loss: 0.5532 - val_accuracy: 1.0000
# Epoch 58/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6072 - accuracy: 0.9776
# Epoch 58: val_loss did not improve from 0.55319
# 15/15 [==============================] - 2s 105ms/step - loss: 0.6072 - accuracy: 0.9776 - val_loss: 0.5650 - val_accuracy: 0.9688
# Epoch 59/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5977 - accuracy: 0.9776
# Epoch 59: val_loss improved from 0.55319 to 0.54389, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 107ms/step - loss: 0.5977 - accuracy: 0.9776 - val_loss: 0.5439 - val_accuracy: 0.9922
# Epoch 60/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5893 - accuracy: 0.9797
# Epoch 60: val_loss improved from 0.54389 to 0.52692, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 107ms/step - loss: 0.5893 - accuracy: 0.9797 - val_loss: 0.5269 - val_accuracy: 1.0000
# Epoch 61/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5772 - accuracy: 0.9744
# Epoch 61: val_loss improved from 0.52692 to 0.51766, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 111ms/step - loss: 0.5772 - accuracy: 0.9744 - val_loss: 0.5177 - val_accuracy: 1.0000
# Epoch 62/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5698 - accuracy: 0.9722
# Epoch 62: val_loss did not improve from 0.51766
# 15/15 [==============================] - 2s 101ms/step - loss: 0.5698 - accuracy: 0.9722 - val_loss: 0.5210 - val_accuracy: 0.9922
# Epoch 63/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5610 - accuracy: 0.9733
# Epoch 63: val_loss improved from 0.51766 to 0.50418, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 112ms/step - loss: 0.5610 - accuracy: 0.9733 - val_loss: 0.5042 - val_accuracy: 1.0000
# Epoch 64/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5502 - accuracy: 0.9776
# Epoch 64: val_loss improved from 0.50418 to 0.49823, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 108ms/step - loss: 0.5502 - accuracy: 0.9776 - val_loss: 0.4982 - val_accuracy: 1.0000
# Epoch 65/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.9776
# Epoch 65: val_loss improved from 0.49823 to 0.48821, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 105ms/step - loss: 0.5376 - accuracy: 0.9776 - val_loss: 0.4882 - val_accuracy: 1.0000
# Epoch 66/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5388 - accuracy: 0.9754
# Epoch 66: val_loss improved from 0.48821 to 0.47623, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 104ms/step - loss: 0.5388 - accuracy: 0.9754 - val_loss: 0.4762 - val_accuracy: 1.0000
# Epoch 67/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5306 - accuracy: 0.9722
# Epoch 67: val_loss did not improve from 0.47623
# 15/15 [==============================] - 2s 100ms/step - loss: 0.5306 - accuracy: 0.9722 - val_loss: 0.4907 - val_accuracy: 0.9766
# Epoch 68/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5472 - accuracy: 0.9712
# Epoch 68: val_loss improved from 0.47623 to 0.47484, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 111ms/step - loss: 0.5472 - accuracy: 0.9712 - val_loss: 0.4748 - val_accuracy: 1.0000
# Epoch 69/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5234 - accuracy: 0.9733
# Epoch 69: val_loss did not improve from 0.47484
# 15/15 [==============================] - 2s 106ms/step - loss: 0.5234 - accuracy: 0.9733 - val_loss: 0.4792 - val_accuracy: 0.9922
# Epoch 70/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5185 - accuracy: 0.9744
# Epoch 70: val_loss improved from 0.47484 to 0.45947, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 111ms/step - loss: 0.5185 - accuracy: 0.9744 - val_loss: 0.4595 - val_accuracy: 1.0000
# Epoch 71/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5142 - accuracy: 0.9701
# Epoch 71: val_loss improved from 0.45947 to 0.45471, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 111ms/step - loss: 0.5142 - accuracy: 0.9701 - val_loss: 0.4547 - val_accuracy: 1.0000
# Epoch 72/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5007 - accuracy: 0.9765
# Epoch 72: val_loss did not improve from 0.45471
# 15/15 [==============================] - 2s 103ms/step - loss: 0.5007 - accuracy: 0.9765 - val_loss: 0.4591 - val_accuracy: 0.9922
# Epoch 73/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.9733
# Epoch 73: val_loss did not improve from 0.45471
# 15/15 [==============================] - 2s 109ms/step - loss: 0.4968 - accuracy: 0.9733 - val_loss: 0.4777 - val_accuracy: 0.9922
# Epoch 74/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4983 - accuracy: 0.9690
# Epoch 74: val_loss did not improve from 0.45471
# 15/15 [==============================] - 2s 101ms/step - loss: 0.4983 - accuracy: 0.9690 - val_loss: 0.4985 - val_accuracy: 0.9844
# Epoch 75/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4849 - accuracy: 0.9754
# Epoch 75: val_loss improved from 0.45471 to 0.42723, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 110ms/step - loss: 0.4849 - accuracy: 0.9754 - val_loss: 0.4272 - val_accuracy: 1.0000
# Epoch 76/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4739 - accuracy: 0.9786
# Epoch 76: val_loss improved from 0.42723 to 0.42138, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 109ms/step - loss: 0.4739 - accuracy: 0.9786 - val_loss: 0.4214 - val_accuracy: 1.0000
# Epoch 77/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4783 - accuracy: 0.9740
# Epoch 77: val_loss did not improve from 0.42138
# 15/15 [==============================] - 2s 104ms/step - loss: 0.4783 - accuracy: 0.9740 - val_loss: 0.4327 - val_accuracy: 0.9922
# Epoch 78/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4676 - accuracy: 0.9765
# Epoch 78: val_loss improved from 0.42138 to 0.42087, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 106ms/step - loss: 0.4676 - accuracy: 0.9765 - val_loss: 0.4209 - val_accuracy: 0.9922
# Epoch 79/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4602 - accuracy: 0.9765
# Epoch 79: val_loss improved from 0.42087 to 0.40989, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 101ms/step - loss: 0.4602 - accuracy: 0.9765 - val_loss: 0.4099 - val_accuracy: 1.0000
# Epoch 80/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4504 - accuracy: 0.9797
# Epoch 80: val_loss improved from 0.40989 to 0.39744, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 107ms/step - loss: 0.4504 - accuracy: 0.9797 - val_loss: 0.3974 - val_accuracy: 1.0000
# Epoch 81/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4602 - accuracy: 0.9776
# Epoch 81: val_loss did not improve from 0.39744
# 15/15 [==============================] - 1s 98ms/step - loss: 0.4602 - accuracy: 0.9776 - val_loss: 0.4061 - val_accuracy: 0.9922
# Epoch 82/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4566 - accuracy: 0.9776
# Epoch 82: val_loss did not improve from 0.39744
# 15/15 [==============================] - 2s 104ms/step - loss: 0.4566 - accuracy: 0.9776 - val_loss: 0.4017 - val_accuracy: 0.9922
# Epoch 83/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4455 - accuracy: 0.9765
# Epoch 83: val_loss improved from 0.39744 to 0.39711, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 108ms/step - loss: 0.4455 - accuracy: 0.9765 - val_loss: 0.3971 - val_accuracy: 1.0000
# Epoch 84/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4595 - accuracy: 0.9677
# Epoch 84: val_loss did not improve from 0.39711
# 15/15 [==============================] - 2s 104ms/step - loss: 0.4595 - accuracy: 0.9677 - val_loss: 0.4145 - val_accuracy: 0.9922
# Epoch 85/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4446 - accuracy: 0.9744
# Epoch 85: val_loss improved from 0.39711 to 0.38580, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 111ms/step - loss: 0.4446 - accuracy: 0.9744 - val_loss: 0.3858 - val_accuracy: 1.0000
# Epoch 86/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4352 - accuracy: 0.9765
# Epoch 86: val_loss improved from 0.38580 to 0.37749, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 112ms/step - loss: 0.4352 - accuracy: 0.9765 - val_loss: 0.3775 - val_accuracy: 1.0000
# Epoch 87/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4320 - accuracy: 0.9792
# Epoch 87: val_loss did not improve from 0.37749
# 15/15 [==============================] - 1s 99ms/step - loss: 0.4320 - accuracy: 0.9792 - val_loss: 0.3812 - val_accuracy: 1.0000
# Epoch 88/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4422 - accuracy: 0.9701
# Epoch 88: val_loss did not improve from 0.37749
# 15/15 [==============================] - 1s 93ms/step - loss: 0.4422 - accuracy: 0.9701 - val_loss: 0.3788 - val_accuracy: 1.0000
# Epoch 89/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4228 - accuracy: 0.9786
# Epoch 89: val_loss improved from 0.37749 to 0.37614, saving model to best_model_C12.h5
# 15/15 [==============================] - 1s 94ms/step - loss: 0.4228 - accuracy: 0.9786 - val_loss: 0.3761 - val_accuracy: 1.0000
# Epoch 90/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4170 - accuracy: 0.9776
# Epoch 90: val_loss did not improve from 0.37614
# 15/15 [==============================] - 1s 88ms/step - loss: 0.4170 - accuracy: 0.9776 - val_loss: 0.3775 - val_accuracy: 0.9922
# Epoch 91/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4220 - accuracy: 0.9722
# Epoch 91: val_loss improved from 0.37614 to 0.36344, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 106ms/step - loss: 0.4220 - accuracy: 0.9722 - val_loss: 0.3634 - val_accuracy: 1.0000
# Epoch 92/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4180 - accuracy: 0.9722
# Epoch 92: val_loss did not improve from 0.36344
# 15/15 [==============================] - 1s 95ms/step - loss: 0.4180 - accuracy: 0.9722 - val_loss: 0.3708 - val_accuracy: 1.0000
# Epoch 93/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4119 - accuracy: 0.9722
# Epoch 93: val_loss improved from 0.36344 to 0.35583, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 102ms/step - loss: 0.4119 - accuracy: 0.9722 - val_loss: 0.3558 - val_accuracy: 0.9922
# Epoch 94/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4194 - accuracy: 0.9744
# Epoch 94: val_loss did not improve from 0.35583
# 15/15 [==============================] - 1s 98ms/step - loss: 0.4194 - accuracy: 0.9744 - val_loss: 0.3670 - val_accuracy: 0.9922
# Epoch 95/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4150 - accuracy: 0.9797
# Epoch 95: val_loss improved from 0.35583 to 0.35416, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 110ms/step - loss: 0.4150 - accuracy: 0.9797 - val_loss: 0.3542 - val_accuracy: 1.0000
# Epoch 96/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4001 - accuracy: 0.9765
# Epoch 96: val_loss improved from 0.35416 to 0.34642, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 110ms/step - loss: 0.4001 - accuracy: 0.9765 - val_loss: 0.3464 - val_accuracy: 1.0000
# Epoch 97/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4117 - accuracy: 0.9744
# Epoch 97: val_loss did not improve from 0.34642
# 15/15 [==============================] - 2s 106ms/step - loss: 0.4117 - accuracy: 0.9744 - val_loss: 0.3594 - val_accuracy: 0.9922
# Epoch 98/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.9765
# Epoch 98: val_loss did not improve from 0.34642
# 15/15 [==============================] - 2s 101ms/step - loss: 0.3957 - accuracy: 0.9765 - val_loss: 0.3477 - val_accuracy: 1.0000
# Epoch 99/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3924 - accuracy: 0.9812
# Epoch 99: val_loss improved from 0.34642 to 0.34420, saving model to best_model_C12.h5
# 15/15 [==============================] - 2s 106ms/step - loss: 0.3924 - accuracy: 0.9812 - val_loss: 0.3442 - val_accuracy: 1.0000
# Epoch 100/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3891 - accuracy: 0.9776
# Epoch 100: val_loss did not improve from 0.34420
# 15/15 [==============================] - 2s 104ms/step - loss: 0.3891 - accuracy: 0.9776 - val_loss: 0.3554 - val_accuracy: 0.9688
# 2/2 [==============================] - 0s 234ms/step - loss: 0.3867 - accuracy: 0.9762
# Test Loss: 0.3867238759994507
# Test Accuracy: 0.976190447807312

# %%
# Graficar precisión y pérdida
plt.figure(figsize=(12, 5))

# Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Línea para Test
plt.title('Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.text(len(history.history['accuracy']) - 1, test_accuracy, f'Test Accuracy: {test_accuracy:.2f}', color='r', ha='center')


# Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')  # Línea para Test
plt.title('Cross Entropy Loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.text(len(history.history['loss']) - 1, test_loss, f'Test Loss: {test_loss:.2f}', color='r', ha='center')

plt.show()
