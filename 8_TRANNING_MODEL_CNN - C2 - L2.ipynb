# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import SGD

# %%
# Directorios de entrenamiento, validación y prueba TAMBIEN MODIFICAR NUM_CLASS Y BEST_MODEL 
train_dir = r'D:\Python\TESIS\CLUSTERS_C2_CALC_K\train'
val_dir = r'D:\Python\TESIS\CLUSTERS_C2_CALC_K\val'
test_dir = r'D:\Python\TESIS\CLUSTERS_C2_CALC_K\test'

# %%
# Configurar TensorFlow para que use solo la GPU 0 y optimizar el uso de la memoria
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU configurada correctamente.")
    except RuntimeError as e:
        print(e)

# Parámetros de la red y del entrenamiento
img_width, img_height = 170, 170  # Ajustado al lienzo de 170x170 píxeles
batch_size = 64
epochs = 100
num_classes = 5  # Número de categorías
l2 = 0.02 

# Generadores de datos para la carga y preprocesamiento de imágenes en escala de grises
train_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Generadores para train, val y test
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)  # No se necesita barajar para evaluar
# Out:
# GPU configurada correctamente.
# Found 2530 images belonging to 5 classes.
# Found 329 images belonging to 5 classes.
# Found 170 images belonging to 5 classes.

# %%
# Crear el modelo
model = Sequential()

# Primera capa convolucional con regularización L2
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 1), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Segunda capa convolucional con regularización L2
model.add(Conv2D(32, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Tercera capa convolucional con regularización L2
model.add(Conv2D(64, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))

# Cuarta capa convolucional con regularización L2
model.add(Conv2D(64, (3, 3), kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Aplanar las capas convolucionales para conectarlas con capas densas
model.add(Flatten())

# Capa densa con regularización L2 y Dropout
model.add(Dense(128, kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Capa de salida
model.add(Dense(num_classes, kernel_regularizer=regularizers.l2(l2)))
model.add(Activation('softmax'))

# Compilar el modelo con el optimizador SGD, una tasa de aprendizaje inicial baja y decaimiento
#optimizer = SGD(learning_rate=1e-4, momentum=0.9, decay=1e-6)
optimizer=Adam(learning_rate=1e-4)

# Configuración del modelo de entrenamiento
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Callbacks para guardar el mejor modelo y detener temprano
checkpoint = ModelCheckpoint('best_model_C2.h5', verbose=1, save_best_only=True, monitor='val_loss', mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

# Entrenamiento del modelo
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[checkpoint, early_stopping],
    workers=tf.data.experimental.AUTOTUNE,
    use_multiprocessing=True)

# Evaluación del modelo en el conjunto de prueba
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# 39/39 [==============================] - ETA: 0s - loss: 8.2382 - accuracy: 0.2648
# Epoch 1: val_loss improved from inf to 6.88995, saving model to best_model_C2.h5
# 39/39 [==============================] - 9s 127ms/step - loss: 8.2382 - accuracy: 0.2648 - val_loss: 6.8900 - val_accuracy: 0.7844
# Epoch 2/100
# 39/39 [==============================] - ETA: 0s - loss: 6.0059 - accuracy: 0.4307
# Epoch 2: val_loss improved from 6.88995 to 5.16922, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 108ms/step - loss: 6.0059 - accuracy: 0.4307 - val_loss: 5.1692 - val_accuracy: 0.6719
# Epoch 3/100
# 39/39 [==============================] - ETA: 0s - loss: 4.5335 - accuracy: 0.5985
# Epoch 3: val_loss improved from 5.16922 to 3.75343, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 109ms/step - loss: 4.5335 - accuracy: 0.5985 - val_loss: 3.7534 - val_accuracy: 0.8625
# Epoch 4/100
# 39/39 [==============================] - ETA: 0s - loss: 3.5831 - accuracy: 0.7080
# Epoch 4: val_loss improved from 3.75343 to 3.02863, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 104ms/step - loss: 3.5831 - accuracy: 0.7080 - val_loss: 3.0286 - val_accuracy: 0.8531
# Epoch 5/100
# 39/39 [==============================] - ETA: 0s - loss: 3.0213 - accuracy: 0.7928
# Epoch 5: val_loss improved from 3.02863 to 2.59394, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 100ms/step - loss: 3.0213 - accuracy: 0.7928 - val_loss: 2.5939 - val_accuracy: 0.9125
# Epoch 6/100
# 39/39 [==============================] - ETA: 0s - loss: 2.6446 - accuracy: 0.8398
# Epoch 6: val_loss improved from 2.59394 to 2.34717, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 100ms/step - loss: 2.6446 - accuracy: 0.8398 - val_loss: 2.3472 - val_accuracy: 0.9438
# Epoch 7/100
# 39/39 [==============================] - ETA: 0s - loss: 2.3944 - accuracy: 0.8690
# Epoch 7: val_loss improved from 2.34717 to 2.12711, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 100ms/step - loss: 2.3944 - accuracy: 0.8690 - val_loss: 2.1271 - val_accuracy: 0.9625
# Epoch 8/100
# 39/39 [==============================] - ETA: 0s - loss: 2.1900 - accuracy: 0.8881
# Epoch 8: val_loss improved from 2.12711 to 2.03049, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 104ms/step - loss: 2.1900 - accuracy: 0.8881 - val_loss: 2.0305 - val_accuracy: 0.9438
# Epoch 9/100
# 39/39 [==============================] - ETA: 0s - loss: 2.0400 - accuracy: 0.8958
# Epoch 9: val_loss did not improve from 2.03049
# 39/39 [==============================] - 4s 104ms/step - loss: 2.0400 - accuracy: 0.8958 - val_loss: 2.0375 - val_accuracy: 0.8781
# Epoch 10/100
# 39/39 [==============================] - ETA: 0s - loss: 1.8907 - accuracy: 0.9189
# Epoch 10: val_loss improved from 2.03049 to 1.82793, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 103ms/step - loss: 1.8907 - accuracy: 0.9189 - val_loss: 1.8279 - val_accuracy: 0.9094
# Epoch 11/100
# 39/39 [==============================] - ETA: 0s - loss: 1.7541 - accuracy: 0.9282
# Epoch 11: val_loss improved from 1.82793 to 1.69705, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 104ms/step - loss: 1.7541 - accuracy: 0.9282 - val_loss: 1.6970 - val_accuracy: 0.9312
# Epoch 12/100
# 39/39 [==============================] - ETA: 0s - loss: 1.6705 - accuracy: 0.9327
# Epoch 12: val_loss did not improve from 1.69705
# 39/39 [==============================] - 4s 110ms/step - loss: 1.6705 - accuracy: 0.9327 - val_loss: 1.7295 - val_accuracy: 0.8938
# Epoch 13/100
# 39/39 [==============================] - ETA: 0s - loss: 1.5733 - accuracy: 0.9392
# Epoch 13: val_loss improved from 1.69705 to 1.49621, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 101ms/step - loss: 1.5733 - accuracy: 0.9392 - val_loss: 1.4962 - val_accuracy: 0.9688
# Epoch 14/100
# 39/39 [==============================] - ETA: 0s - loss: 1.5076 - accuracy: 0.9392
# Epoch 14: val_loss improved from 1.49621 to 1.49015, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 104ms/step - loss: 1.5076 - accuracy: 0.9392 - val_loss: 1.4902 - val_accuracy: 0.9312
# Epoch 15/100
# 39/39 [==============================] - ETA: 0s - loss: 1.4383 - accuracy: 0.9436
# Epoch 15: val_loss improved from 1.49015 to 1.42998, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 105ms/step - loss: 1.4383 - accuracy: 0.9436 - val_loss: 1.4300 - val_accuracy: 0.9375
# Epoch 16/100
# 39/39 [==============================] - ETA: 0s - loss: 1.3801 - accuracy: 0.9444
# Epoch 16: val_loss improved from 1.42998 to 1.32084, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 102ms/step - loss: 1.3801 - accuracy: 0.9444 - val_loss: 1.3208 - val_accuracy: 0.9500
# Epoch 17/100
# 39/39 [==============================] - ETA: 0s - loss: 1.3287 - accuracy: 0.9473
# Epoch 17: val_loss improved from 1.32084 to 1.30879, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 95ms/step - loss: 1.3287 - accuracy: 0.9473 - val_loss: 1.3088 - val_accuracy: 0.9438
# Epoch 18/100
# 39/39 [==============================] - ETA: 0s - loss: 1.2997 - accuracy: 0.9384
# Epoch 18: val_loss did not improve from 1.30879
# 39/39 [==============================] - 4s 99ms/step - loss: 1.2997 - accuracy: 0.9384 - val_loss: 1.4027 - val_accuracy: 0.8938
# Epoch 19/100
# 39/39 [==============================] - ETA: 0s - loss: 1.2455 - accuracy: 0.9444
# Epoch 19: val_loss improved from 1.30879 to 1.27266, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 99ms/step - loss: 1.2455 - accuracy: 0.9444 - val_loss: 1.2727 - val_accuracy: 0.9156
# Epoch 20/100
# 39/39 [==============================] - ETA: 0s - loss: 1.2015 - accuracy: 0.9497
# Epoch 20: val_loss improved from 1.27266 to 1.13486, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 105ms/step - loss: 1.2015 - accuracy: 0.9497 - val_loss: 1.1349 - val_accuracy: 0.9656
# Epoch 21/100
# 39/39 [==============================] - ETA: 0s - loss: 1.1715 - accuracy: 0.9481
# Epoch 21: val_loss did not improve from 1.13486
# 39/39 [==============================] - 4s 100ms/step - loss: 1.1715 - accuracy: 0.9481 - val_loss: 1.1739 - val_accuracy: 0.9250
# Epoch 22/100
# 39/39 [==============================] - ETA: 0s - loss: 1.1455 - accuracy: 0.9489
# Epoch 22: val_loss improved from 1.13486 to 1.08653, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 104ms/step - loss: 1.1455 - accuracy: 0.9489 - val_loss: 1.0865 - val_accuracy: 0.9625
# Epoch 23/100
# 39/39 [==============================] - ETA: 0s - loss: 1.1186 - accuracy: 0.9424
# Epoch 23: val_loss did not improve from 1.08653
# 39/39 [==============================] - 4s 111ms/step - loss: 1.1186 - accuracy: 0.9424 - val_loss: 1.1243 - val_accuracy: 0.9219
# Epoch 24/100
# 39/39 [==============================] - ETA: 0s - loss: 1.0892 - accuracy: 0.9477
# Epoch 24: val_loss improved from 1.08653 to 1.08158, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 111ms/step - loss: 1.0892 - accuracy: 0.9477 - val_loss: 1.0816 - val_accuracy: 0.9500
# Epoch 25/100
# 39/39 [==============================] - ETA: 0s - loss: 1.0639 - accuracy: 0.9485
# Epoch 25: val_loss improved from 1.08158 to 1.04941, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 105ms/step - loss: 1.0639 - accuracy: 0.9485 - val_loss: 1.0494 - val_accuracy: 0.9531
# Epoch 26/100
# 39/39 [==============================] - ETA: 0s - loss: 1.0370 - accuracy: 0.9501
# Epoch 26: val_loss did not improve from 1.04941
# 39/39 [==============================] - 4s 93ms/step - loss: 1.0370 - accuracy: 0.9501 - val_loss: 1.0557 - val_accuracy: 0.9500
# Epoch 27/100
# 39/39 [==============================] - ETA: 0s - loss: 1.0110 - accuracy: 0.9562
# Epoch 27: val_loss improved from 1.04941 to 1.00396, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 103ms/step - loss: 1.0110 - accuracy: 0.9562 - val_loss: 1.0040 - val_accuracy: 0.9531
# Epoch 28/100
# 39/39 [==============================] - ETA: 0s - loss: 0.9960 - accuracy: 0.9511
# Epoch 28: val_loss did not improve from 1.00396
# 39/39 [==============================] - 4s 105ms/step - loss: 0.9960 - accuracy: 0.9511 - val_loss: 1.0117 - val_accuracy: 0.9531
# Epoch 29/100
# 39/39 [==============================] - ETA: 0s - loss: 0.9665 - accuracy: 0.9594
# Epoch 29: val_loss did not improve from 1.00396
# 39/39 [==============================] - 4s 90ms/step - loss: 0.9665 - accuracy: 0.9594 - val_loss: 1.0071 - val_accuracy: 0.9469
# Epoch 30/100
# 39/39 [==============================] - ETA: 0s - loss: 0.9500 - accuracy: 0.9562
# Epoch 30: val_loss improved from 1.00396 to 0.99669, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 96ms/step - loss: 0.9500 - accuracy: 0.9562 - val_loss: 0.9967 - val_accuracy: 0.9375
# Epoch 31/100
# 39/39 [==============================] - ETA: 0s - loss: 0.9234 - accuracy: 0.9615
# Epoch 31: val_loss improved from 0.99669 to 0.97248, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 104ms/step - loss: 0.9234 - accuracy: 0.9615 - val_loss: 0.9725 - val_accuracy: 0.9406
# Epoch 32/100
# 39/39 [==============================] - ETA: 0s - loss: 0.9178 - accuracy: 0.9558
# Epoch 32: val_loss did not improve from 0.97248
# 39/39 [==============================] - 4s 103ms/step - loss: 0.9178 - accuracy: 0.9558 - val_loss: 0.9899 - val_accuracy: 0.9156
# Epoch 33/100
# 39/39 [==============================] - ETA: 0s - loss: 0.9030 - accuracy: 0.9611
# Epoch 33: val_loss did not improve from 0.97248
# 39/39 [==============================] - 4s 107ms/step - loss: 0.9030 - accuracy: 0.9611 - val_loss: 0.9731 - val_accuracy: 0.9375
# Epoch 34/100
# 39/39 [==============================] - ETA: 0s - loss: 0.8986 - accuracy: 0.9570
# Epoch 34: val_loss improved from 0.97248 to 0.87850, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 108ms/step - loss: 0.8986 - accuracy: 0.9570 - val_loss: 0.8785 - val_accuracy: 0.9625
# Epoch 35/100
# 39/39 [==============================] - ETA: 0s - loss: 0.8806 - accuracy: 0.9578
# Epoch 35: val_loss did not improve from 0.87850
# 39/39 [==============================] - 4s 115ms/step - loss: 0.8806 - accuracy: 0.9578 - val_loss: 0.8958 - val_accuracy: 0.9500
# Epoch 36/100
# 39/39 [==============================] - ETA: 0s - loss: 0.8694 - accuracy: 0.9615
# Epoch 36: val_loss improved from 0.87850 to 0.87674, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 110ms/step - loss: 0.8694 - accuracy: 0.9615 - val_loss: 0.8767 - val_accuracy: 0.9531
# Epoch 37/100
# 39/39 [==============================] - ETA: 0s - loss: 0.8673 - accuracy: 0.9509
# Epoch 37: val_loss improved from 0.87674 to 0.84363, saving model to best_model_C2.h5
# 39/39 [==============================] - 3s 88ms/step - loss: 0.8673 - accuracy: 0.9509 - val_loss: 0.8436 - val_accuracy: 0.9688
# Epoch 38/100
# 39/39 [==============================] - ETA: 0s - loss: 0.8398 - accuracy: 0.9590
# Epoch 38: val_loss improved from 0.84363 to 0.82904, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 102ms/step - loss: 0.8398 - accuracy: 0.9590 - val_loss: 0.8290 - val_accuracy: 0.9625
# Epoch 39/100
# 39/39 [==============================] - ETA: 0s - loss: 0.8280 - accuracy: 0.9582
# Epoch 39: val_loss did not improve from 0.82904
# 39/39 [==============================] - 4s 102ms/step - loss: 0.8280 - accuracy: 0.9582 - val_loss: 0.9191 - val_accuracy: 0.9281
# Epoch 40/100
# 39/39 [==============================] - ETA: 0s - loss: 0.8324 - accuracy: 0.9570
# Epoch 40: val_loss did not improve from 0.82904
# 39/39 [==============================] - 4s 100ms/step - loss: 0.8324 - accuracy: 0.9570 - val_loss: 0.8855 - val_accuracy: 0.9281
# Epoch 41/100
# 39/39 [==============================] - ETA: 0s - loss: 0.8197 - accuracy: 0.9542
# Epoch 41: val_loss did not improve from 0.82904
# 39/39 [==============================] - 4s 105ms/step - loss: 0.8197 - accuracy: 0.9542 - val_loss: 0.9571 - val_accuracy: 0.8938
# Epoch 42/100
# 39/39 [==============================] - ETA: 0s - loss: 0.8164 - accuracy: 0.9546
# Epoch 42: val_loss did not improve from 0.82904
# 39/39 [==============================] - 4s 99ms/step - loss: 0.8164 - accuracy: 0.9546 - val_loss: 0.8845 - val_accuracy: 0.9187
# Epoch 43/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7986 - accuracy: 0.9615
# Epoch 43: val_loss improved from 0.82904 to 0.79191, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 105ms/step - loss: 0.7986 - accuracy: 0.9615 - val_loss: 0.7919 - val_accuracy: 0.9656
# Epoch 44/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7861 - accuracy: 0.9667
# Epoch 44: val_loss did not improve from 0.79191
# 39/39 [==============================] - 4s 103ms/step - loss: 0.7861 - accuracy: 0.9667 - val_loss: 0.8349 - val_accuracy: 0.9406
# Epoch 45/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7786 - accuracy: 0.9623
# Epoch 45: val_loss did not improve from 0.79191
# 39/39 [==============================] - 4s 101ms/step - loss: 0.7786 - accuracy: 0.9623 - val_loss: 0.7927 - val_accuracy: 0.9563
# Epoch 46/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7763 - accuracy: 0.9611
# Epoch 46: val_loss did not improve from 0.79191
# 39/39 [==============================] - 4s 102ms/step - loss: 0.7763 - accuracy: 0.9611 - val_loss: 0.7975 - val_accuracy: 0.9500
# Epoch 47/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7773 - accuracy: 0.9567
# Epoch 47: val_loss improved from 0.79191 to 0.79148, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 103ms/step - loss: 0.7773 - accuracy: 0.9567 - val_loss: 0.7915 - val_accuracy: 0.9594
# Epoch 48/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7533 - accuracy: 0.9590
# Epoch 48: val_loss did not improve from 0.79148
# 39/39 [==============================] - 4s 102ms/step - loss: 0.7533 - accuracy: 0.9590 - val_loss: 0.8064 - val_accuracy: 0.9469
# Epoch 49/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7612 - accuracy: 0.9578
# Epoch 49: val_loss improved from 0.79148 to 0.76500, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 93ms/step - loss: 0.7612 - accuracy: 0.9578 - val_loss: 0.7650 - val_accuracy: 0.9531
# Epoch 50/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7440 - accuracy: 0.9655
# Epoch 50: val_loss improved from 0.76500 to 0.76488, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 104ms/step - loss: 0.7440 - accuracy: 0.9655 - val_loss: 0.7649 - val_accuracy: 0.9563
# Epoch 51/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7485 - accuracy: 0.9570
# Epoch 51: val_loss improved from 0.76488 to 0.73389, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 106ms/step - loss: 0.7485 - accuracy: 0.9570 - val_loss: 0.7339 - val_accuracy: 0.9625
# Epoch 52/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7344 - accuracy: 0.9586
# Epoch 52: val_loss did not improve from 0.73389
# 39/39 [==============================] - 4s 92ms/step - loss: 0.7344 - accuracy: 0.9586 - val_loss: 0.7504 - val_accuracy: 0.9500
# Epoch 53/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7201 - accuracy: 0.9667
# Epoch 53: val_loss did not improve from 0.73389
# 39/39 [==============================] - 3s 88ms/step - loss: 0.7201 - accuracy: 0.9667 - val_loss: 0.8865 - val_accuracy: 0.8969
# Epoch 54/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7403 - accuracy: 0.9538
# Epoch 54: val_loss did not improve from 0.73389
# 39/39 [==============================] - 4s 96ms/step - loss: 0.7403 - accuracy: 0.9538 - val_loss: 0.8012 - val_accuracy: 0.9250
# Epoch 55/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7198 - accuracy: 0.9574
# Epoch 55: val_loss did not improve from 0.73389
# 39/39 [==============================] - 4s 97ms/step - loss: 0.7198 - accuracy: 0.9574 - val_loss: 0.7524 - val_accuracy: 0.9469
# Epoch 56/100
# 39/39 [==============================] - ETA: 0s - loss: 0.7065 - accuracy: 0.9643
# Epoch 56: val_loss improved from 0.73389 to 0.71288, saving model to best_model_C2.h5
# 39/39 [==============================] - 4s 103ms/step - loss: 0.7065 - accuracy: 0.9643 - val_loss: 0.7129 - val_accuracy: 0.9625
# Epoch 57/100
# 39/39 [==============================] - ETA: 0s - loss: 0.6981 - accuracy: 0.9663
# Epoch 57: val_loss did not improve from 0.71288
# 39/39 [==============================] - 4s 105ms/step - loss: 0.6981 - accuracy: 0.9663 - val_loss: 0.8389 - val_accuracy: 0.9000
# Epoch 58/100
# 39/39 [==============================] - ETA: 0s - loss: 0.6953 - accuracy: 0.9684
# Epoch 58: val_loss did not improve from 0.71288
# 39/39 [==============================] - 4s 97ms/step - loss: 0.6953 - accuracy: 0.9684 - val_loss: 0.7510 - val_accuracy: 0.9469
# Epoch 59/100
# 39/39 [==============================] - ETA: 0s - loss: 0.6960 - accuracy: 0.9619
# Epoch 59: val_loss did not improve from 0.71288
# 39/39 [==============================] - 4s 95ms/step - loss: 0.6960 - accuracy: 0.9619 - val_loss: 0.7476 - val_accuracy: 0.9500
# Epoch 60/100
# 39/39 [==============================] - ETA: 0s - loss: 0.6841 - accuracy: 0.9623
# Epoch 60: val_loss did not improve from 0.71288
# 39/39 [==============================] - 4s 102ms/step - loss: 0.6841 - accuracy: 0.9623 - val_loss: 0.8513 - val_accuracy: 0.8906
# Epoch 61/100
# 39/39 [==============================] - ETA: 0s - loss: 0.6895 - accuracy: 0.9611
# Epoch 61: val_loss did not improve from 0.71288
# 39/39 [==============================] - 4s 99ms/step - loss: 0.6895 - accuracy: 0.9611 - val_loss: 0.7618 - val_accuracy: 0.9344
# Epoch 61: early stopping
# 3/3 [==============================] - 1s 190ms/step - loss: 0.7486 - accuracy: 0.9176
# Test Loss: 0.7486022114753723
# Test Accuracy: 0.9176470637321472

# %%
# Graficar precisión y pérdida
plt.figure(figsize=(12, 5))

# Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Línea para Test
plt.title('Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.text(len(history.history['accuracy']) - 1, test_accuracy, f'Test Accuracy: {test_accuracy:.2f}', color='r', ha='center')


# Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')  # Línea para Test
plt.title('Cross Entropy Loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.text(len(history.history['loss']) - 1, test_loss, f'Test Loss: {test_loss:.2f}', color='r', ha='center')

plt.show()
