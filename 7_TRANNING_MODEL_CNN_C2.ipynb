# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt

# %%
# Directorios de entrenamiento, validación y prueba
train_dir = r'D:\Python\TESIS\CLUSTERS_C2_CALC_K\train'
val_dir = r'D:\Python\TESIS\CLUSTERS_C2_CALC_K\val'
test_dir = r'D:\Python\TESIS\CLUSTERS_C2_CALC_K\test'

# %%
# Configurar TensorFlow para que use solo la GPU 0 y optimizar el uso de la memoria
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU configurada correctamente.")
    except RuntimeError as e:
        print(e)

# Parámetros de la red y del entrenamiento
img_width, img_height = 170, 170  # Ajustado al lienzo de 170x170 píxeles
batch_size = 32
epochs = 50
num_classes = 5  # Número de categorías
# Out:
# GPU configurada correctamente.

# %%
# Generadores de datos para la carga y preprocesamiento de imágenes en escala de grises
train_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Generadores para train, val y test
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)  # No se necesita barajar para evaluar

# Construcción de la red neuronal convolucional
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# Configuración del modelo de entrenamiento
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=1e-4),
              metrics=['accuracy'])

# Callbacks para guardar el mejor modelo y detener temprano
checkpoint = ModelCheckpoint('best_model_C2.h5', verbose=1, save_best_only=True, monitor='val_loss', mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

# Entrenamiento del modelo
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[checkpoint, early_stopping],
    workers=tf.data.experimental.AUTOTUNE,
    use_multiprocessing=True)

# Evaluación del modelo en el conjunto de prueba
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Found 2530 images belonging to 5 classes.
# Found 329 images belonging to 5 classes.
# Found 170 images belonging to 5 classes.
# Epoch 1/50
# 79/79 [==============================] - ETA: 0s - loss: 1.5138 - accuracy: 0.3479
# Epoch 1: val_loss improved from inf to 1.16310, saving model to best_model.h5
# 79/79 [==============================] - 11s 60ms/step - loss: 1.5138 - accuracy: 0.3479 - val_loss: 1.1631 - val_accuracy: 0.7344
# Epoch 2/50
# 79/79 [==============================] - ETA: 0s - loss: 1.0678 - accuracy: 0.5813
# Epoch 2: val_loss improved from 1.16310 to 0.54354, saving model to best_model.h5
# 79/79 [==============================] - 5s 58ms/step - loss: 1.0678 - accuracy: 0.5813 - val_loss: 0.5435 - val_accuracy: 0.9031
# Epoch 3/50
# 79/79 [==============================] - ETA: 0s - loss: 0.7361 - accuracy: 0.7262
# Epoch 3: val_loss improved from 0.54354 to 0.35215, saving model to best_model.h5
# 79/79 [==============================] - 5s 60ms/step - loss: 0.7361 - accuracy: 0.7262 - val_loss: 0.3521 - val_accuracy: 0.9375
# Epoch 4/50
# 78/79 [============================>.] - ETA: 0s - loss: 0.5519 - accuracy: 0.7920
# Epoch 4: val_loss improved from 0.35215 to 0.26898, saving model to best_model.h5
# 79/79 [==============================] - 4s 55ms/step - loss: 0.5532 - accuracy: 0.7910 - val_loss: 0.2690 - val_accuracy: 0.9688
# Epoch 5/50
# 78/79 [============================>.] - ETA: 0s - loss: 0.4616 - accuracy: 0.8321
# Epoch 5: val_loss did not improve from 0.26898
# 79/79 [==============================] - 5s 61ms/step - loss: 0.4612 - accuracy: 0.8323 - val_loss: 0.2765 - val_accuracy: 0.9062
# Epoch 6/50
# 79/79 [==============================] - ETA: 0s - loss: 0.3965 - accuracy: 0.8447
# Epoch 6: val_loss improved from 0.26898 to 0.21690, saving model to best_model.h5
# 79/79 [==============================] - 5s 61ms/step - loss: 0.3965 - accuracy: 0.8447 - val_loss: 0.2169 - val_accuracy: 0.9406
# Epoch 7/50
# 78/79 [============================>.] - ETA: 0s - loss: 0.3522 - accuracy: 0.8706
# Epoch 7: val_loss improved from 0.21690 to 0.19468, saving model to best_model.h5
# 79/79 [==============================] - 5s 65ms/step - loss: 0.3524 - accuracy: 0.8707 - val_loss: 0.1947 - val_accuracy: 0.9438
# Epoch 8/50
# 79/79 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.8731
# Epoch 8: val_loss did not improve from 0.19468
# 79/79 [==============================] - 5s 61ms/step - loss: 0.3303 - accuracy: 0.8731 - val_loss: 0.1953 - val_accuracy: 0.9375
# Epoch 9/50
# 79/79 [==============================] - ETA: 0s - loss: 0.2972 - accuracy: 0.8863
# Epoch 9: val_loss improved from 0.19468 to 0.18940, saving model to best_model.h5
# 79/79 [==============================] - 5s 60ms/step - loss: 0.2972 - accuracy: 0.8863 - val_loss: 0.1894 - val_accuracy: 0.9406
# Epoch 10/50
# 78/79 [============================>.] - ETA: 0s - loss: 0.2790 - accuracy: 0.8921
# Epoch 10: val_loss improved from 0.18940 to 0.14880, saving model to best_model.h5
# 79/79 [==============================] - 5s 60ms/step - loss: 0.2789 - accuracy: 0.8919 - val_loss: 0.1488 - val_accuracy: 0.9656
# Epoch 11/50
# 78/79 [============================>.] - ETA: 0s - loss: 0.2709 - accuracy: 0.8974
# Epoch 11: val_loss did not improve from 0.14880
# 79/79 [==============================] - 5s 58ms/step - loss: 0.2699 - accuracy: 0.8975 - val_loss: 0.1565 - val_accuracy: 0.9688
# Epoch 12/50
# 79/79 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.9103
# Epoch 12: val_loss did not improve from 0.14880
# 79/79 [==============================] - 5s 57ms/step - loss: 0.2379 - accuracy: 0.9103 - val_loss: 0.1969 - val_accuracy: 0.9375
# Epoch 13/50
# 78/79 [============================>.] - ETA: 0s - loss: 0.2207 - accuracy: 0.9213
# Epoch 13: val_loss did not improve from 0.14880
# 79/79 [==============================] - 5s 62ms/step - loss: 0.2222 - accuracy: 0.9207 - val_loss: 0.2421 - val_accuracy: 0.9219
# Epoch 14/50
# 78/79 [============================>.] - ETA: 0s - loss: 0.2204 - accuracy: 0.9169
# Epoch 14: val_loss improved from 0.14880 to 0.14716, saving model to best_model.h5
# 79/79 [==============================] - 5s 58ms/step - loss: 0.2205 - accuracy: 0.9163 - val_loss: 0.1472 - val_accuracy: 0.9656
# Epoch 15/50
# 78/79 [============================>.] - ETA: 0s - loss: 0.2161 - accuracy: 0.9127
# Epoch 15: val_loss did not improve from 0.14716
# 79/79 [==============================] - 5s 62ms/step - loss: 0.2152 - accuracy: 0.9134 - val_loss: 0.2326 - val_accuracy: 0.9125
# Epoch 16/50
# 79/79 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9283
# Epoch 16: val_loss did not improve from 0.14716
# 79/79 [==============================] - 5s 61ms/step - loss: 0.1972 - accuracy: 0.9283 - val_loss: 0.2204 - val_accuracy: 0.9281
# Epoch 17/50
# 79/79 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9167
# Epoch 17: val_loss improved from 0.14716 to 0.14612, saving model to best_model.h5
# 79/79 [==============================] - 5s 63ms/step - loss: 0.2098 - accuracy: 0.9167 - val_loss: 0.1461 - val_accuracy: 0.9750
# Epoch 18/50
# 79/79 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.9167
# Epoch 18: val_loss did not improve from 0.14612
# 79/79 [==============================] - 5s 60ms/step - loss: 0.2028 - accuracy: 0.9167 - val_loss: 0.1600 - val_accuracy: 0.9500
# Epoch 19/50
# 79/79 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9267
# Epoch 19: val_loss did not improve from 0.14612
# 79/79 [==============================] - 5s 63ms/step - loss: 0.1853 - accuracy: 0.9267 - val_loss: 0.1470 - val_accuracy: 0.9625
# Epoch 20/50
# 79/79 [==============================] - ETA: 0s - loss: 0.1762 - accuracy: 0.9291
# Epoch 20: val_loss did not improve from 0.14612
# 79/79 [==============================] - 5s 63ms/step - loss: 0.1762 - accuracy: 0.9291 - val_loss: 0.1664 - val_accuracy: 0.9563
# Epoch 21/50
# 79/79 [==============================] - ETA: 0s - loss: 0.1612 - accuracy: 0.9376
# Epoch 21: val_loss did not improve from 0.14612
# 79/79 [==============================] - 5s 62ms/step - loss: 0.1612 - accuracy: 0.9376 - val_loss: 0.1627 - val_accuracy: 0.9563
# Epoch 22/50
# 79/79 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9267
# Epoch 22: val_loss improved from 0.14612 to 0.10095, saving model to best_model.h5
# 79/79 [==============================] - 5s 61ms/step - loss: 0.1772 - accuracy: 0.9267 - val_loss: 0.1010 - val_accuracy: 0.9563
# Epoch 23/50
# 79/79 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9291
# Epoch 23: val_loss did not improve from 0.10095
# 79/79 [==============================] - 4s 57ms/step - loss: 0.1715 - accuracy: 0.9291 - val_loss: 0.1606 - val_accuracy: 0.9500
# Epoch 24/50
# 79/79 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9259
# Epoch 24: val_loss did not improve from 0.10095
# 79/79 [==============================] - 5s 58ms/step - loss: 0.1714 - accuracy: 0.9259 - val_loss: 0.1538 - val_accuracy: 0.9406
# Epoch 25/50
# 78/79 [============================>.] - ETA: 0s - loss: 0.1643 - accuracy: 0.9290
# Epoch 25: val_loss did not improve from 0.10095
# 79/79 [==============================] - 5s 58ms/step - loss: 0.1636 - accuracy: 0.9295 - val_loss: 0.1595 - val_accuracy: 0.9563
# Epoch 26/50
# 79/79 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9420
# Epoch 26: val_loss did not improve from 0.10095
# 79/79 [==============================] - 4s 57ms/step - loss: 0.1558 - accuracy: 0.9420 - val_loss: 0.1348 - val_accuracy: 0.9719
# Epoch 27/50
# 79/79 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9359
# Epoch 27: val_loss did not improve from 0.10095
# 79/79 [==============================] - 5s 60ms/step - loss: 0.1513 - accuracy: 0.9359 - val_loss: 0.1515 - val_accuracy: 0.9500
# Epoch 27: early stopping
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1085 - accuracy: 0.9412
# Test Loss: 0.10854490101337433
# Test Accuracy: 0.9411764740943909

# %%
# Graficar precisión y pérdida
plt.figure(figsize=(12, 5))

# Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Línea para Test
plt.title('Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.text(len(history.history['accuracy']) - 1, test_accuracy, f'Test Accuracy: {test_accuracy:.2f}', color='r', ha='center')


# Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')  # Línea para Test
plt.title('Cross Entropy Loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.text(len(history.history['loss']) - 1, test_loss, f'Test Loss: {test_loss:.2f}', color='r', ha='center')

plt.show()
