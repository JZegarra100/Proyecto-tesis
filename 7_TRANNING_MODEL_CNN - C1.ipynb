# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt

# %%
# Directorios de entrenamiento, validación y prueba TAMBIEN MODIFICAR NUM_CLASS Y BEST_MODEL 
train_dir = r'D:\Python\TESIS\CLUSTERS_C1_CALC_K\train'
val_dir = r'D:\Python\TESIS\CLUSTERS_C1_CALC_K\val'
test_dir = r'D:\Python\TESIS\CLUSTERS_C1_CALC_K\test'

# %%
# Configurar TensorFlow para que use solo la GPU 0 y optimizar el uso de la memoria
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU configurada correctamente.")
    except RuntimeError as e:
        print(e)

# Parámetros de la red y del entrenamiento
img_width, img_height = 170, 170  # Ajustado al lienzo de 170x170 píxeles
batch_size = 32
epochs = 50
num_classes = 3  # Número de categorías
# Out:
# GPU configurada correctamente.

# %%
# Generadores de datos para la carga y preprocesamiento de imágenes en escala de grises
train_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Generadores para train, val y test
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)  # No se necesita barajar para evaluar

# Construcción de la red neuronal convolucional
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_width, img_height, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# Configuración del modelo de entrenamiento
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=1e-4),
              metrics=['accuracy'])

# Callbacks para guardar el mejor modelo y detener temprano
checkpoint = ModelCheckpoint('best_model_C1.h5', verbose=1, save_best_only=True, monitor='val_loss', mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

# Entrenamiento del modelo
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[checkpoint, early_stopping],
    workers=tf.data.experimental.AUTOTUNE,
    use_multiprocessing=True)

# Evaluación del modelo en el conjunto de prueba
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Found 870 images belonging to 3 classes.
# Found 176 images belonging to 3 classes.
# Found 91 images belonging to 3 classes.
# Epoch 1/50
# 27/27 [==============================] - ETA: 0s - loss: 1.0313 - accuracy: 0.4654
# Epoch 1: val_loss improved from inf to 0.93139, saving model to best_model_C1.h5
# 27/27 [==============================] - 5s 81ms/step - loss: 1.0313 - accuracy: 0.4654 - val_loss: 0.9314 - val_accuracy: 0.8813
# Epoch 2/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.8553 - accuracy: 0.6452
# Epoch 2: val_loss improved from 0.93139 to 0.71446, saving model to best_model_C1.h5
# 27/27 [==============================] - 1s 55ms/step - loss: 0.8495 - accuracy: 0.6444 - val_loss: 0.7145 - val_accuracy: 0.8875
# Epoch 3/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.7203 - accuracy: 0.7035
# Epoch 3: val_loss improved from 0.71446 to 0.61834, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 61ms/step - loss: 0.7147 - accuracy: 0.7053 - val_loss: 0.6183 - val_accuracy: 0.7625
# Epoch 4/50
# 27/27 [==============================] - ETA: 0s - loss: 0.5967 - accuracy: 0.7780
# Epoch 4: val_loss improved from 0.61834 to 0.52977, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 61ms/step - loss: 0.5967 - accuracy: 0.7780 - val_loss: 0.5298 - val_accuracy: 0.8375
# Epoch 5/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.4714 - accuracy: 0.8362
# Epoch 5: val_loss improved from 0.52977 to 0.35579, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 57ms/step - loss: 0.4704 - accuracy: 0.8377 - val_loss: 0.3558 - val_accuracy: 0.9563
# Epoch 6/50
# 27/27 [==============================] - ETA: 0s - loss: 0.4012 - accuracy: 0.8687
# Epoch 6: val_loss improved from 0.35579 to 0.32978, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 57ms/step - loss: 0.4012 - accuracy: 0.8687 - val_loss: 0.3298 - val_accuracy: 0.9062
# Epoch 7/50
# 27/27 [==============================] - ETA: 0s - loss: 0.3133 - accuracy: 0.9033
# Epoch 7: val_loss improved from 0.32978 to 0.21220, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 65ms/step - loss: 0.3133 - accuracy: 0.9033 - val_loss: 0.2122 - val_accuracy: 0.9750
# Epoch 8/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2418 - accuracy: 0.9260
# Epoch 8: val_loss improved from 0.21220 to 0.16266, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 65ms/step - loss: 0.2418 - accuracy: 0.9260 - val_loss: 0.1627 - val_accuracy: 0.9937
# Epoch 9/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2116 - accuracy: 0.9433
# Epoch 9: val_loss did not improve from 0.16266
# 27/27 [==============================] - 2s 59ms/step - loss: 0.2116 - accuracy: 0.9433 - val_loss: 0.1816 - val_accuracy: 0.9312
# Epoch 10/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1785 - accuracy: 0.9558
# Epoch 10: val_loss improved from 0.16266 to 0.07995, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 66ms/step - loss: 0.1785 - accuracy: 0.9558 - val_loss: 0.0799 - val_accuracy: 0.9875
# Epoch 11/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9535
# Epoch 11: val_loss did not improve from 0.07995
# 27/27 [==============================] - 2s 62ms/step - loss: 0.1700 - accuracy: 0.9535 - val_loss: 0.2072 - val_accuracy: 0.9062
# Epoch 12/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9666
# Epoch 12: val_loss improved from 0.07995 to 0.05973, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 60ms/step - loss: 0.1681 - accuracy: 0.9666 - val_loss: 0.0597 - val_accuracy: 0.9937
# Epoch 13/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1675 - accuracy: 0.9594
# Epoch 13: val_loss did not improve from 0.05973
# 27/27 [==============================] - 1s 54ms/step - loss: 0.1675 - accuracy: 0.9594 - val_loss: 0.0707 - val_accuracy: 0.9937
# Epoch 14/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9618
# Epoch 14: val_loss improved from 0.05973 to 0.05841, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 68ms/step - loss: 0.1551 - accuracy: 0.9618 - val_loss: 0.0584 - val_accuracy: 0.9875
# Epoch 15/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1289 - accuracy: 0.9749
# Epoch 15: val_loss improved from 0.05841 to 0.05615, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 62ms/step - loss: 0.1289 - accuracy: 0.9749 - val_loss: 0.0561 - val_accuracy: 0.9937
# Epoch 16/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9702
# Epoch 16: val_loss did not improve from 0.05615
# 27/27 [==============================] - 1s 51ms/step - loss: 0.1309 - accuracy: 0.9702 - val_loss: 0.0726 - val_accuracy: 0.9937
# Epoch 17/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.1234 - accuracy: 0.9736
# Epoch 17: val_loss did not improve from 0.05615
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1239 - accuracy: 0.9737 - val_loss: 0.0710 - val_accuracy: 0.9937
# Epoch 18/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.1276 - accuracy: 0.9727
# Epoch 18: val_loss improved from 0.05615 to 0.04712, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 63ms/step - loss: 0.1250 - accuracy: 0.9737 - val_loss: 0.0471 - val_accuracy: 0.9937
# Epoch 19/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9737
# Epoch 19: val_loss improved from 0.04712 to 0.04333, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 61ms/step - loss: 0.1162 - accuracy: 0.9737 - val_loss: 0.0433 - val_accuracy: 0.9875
# Epoch 20/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.1114 - accuracy: 0.9777
# Epoch 20: val_loss did not improve from 0.04333
# 27/27 [==============================] - 1s 55ms/step - loss: 0.1105 - accuracy: 0.9773 - val_loss: 0.0443 - val_accuracy: 0.9875
# Epoch 21/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9773
# Epoch 21: val_loss improved from 0.04333 to 0.03475, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0945 - accuracy: 0.9773 - val_loss: 0.0347 - val_accuracy: 0.9937
# Epoch 22/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1069 - accuracy: 0.9745
# Epoch 22: val_loss did not improve from 0.03475
# 27/27 [==============================] - 2s 63ms/step - loss: 0.1069 - accuracy: 0.9745 - val_loss: 0.0462 - val_accuracy: 0.9937
# Epoch 23/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0905 - accuracy: 0.9777
# Epoch 23: val_loss did not improve from 0.03475
# 27/27 [==============================] - 2s 64ms/step - loss: 0.0921 - accuracy: 0.9749 - val_loss: 0.0377 - val_accuracy: 0.9937
# Epoch 24/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9737
# Epoch 24: val_loss improved from 0.03475 to 0.02980, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 66ms/step - loss: 0.0924 - accuracy: 0.9737 - val_loss: 0.0298 - val_accuracy: 0.9937
# Epoch 25/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0890 - accuracy: 0.9715
# Epoch 25: val_loss improved from 0.02980 to 0.02547, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 63ms/step - loss: 0.0889 - accuracy: 0.9702 - val_loss: 0.0255 - val_accuracy: 0.9937
# Epoch 26/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9773
# Epoch 26: val_loss did not improve from 0.02547
# 27/27 [==============================] - 2s 58ms/step - loss: 0.0846 - accuracy: 0.9773 - val_loss: 0.0297 - val_accuracy: 0.9937
# Epoch 27/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0851 - accuracy: 0.9814
# Epoch 27: val_loss did not improve from 0.02547
# 27/27 [==============================] - 2s 56ms/step - loss: 0.0846 - accuracy: 0.9809 - val_loss: 0.0521 - val_accuracy: 0.9937
# Epoch 28/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9821
# Epoch 28: val_loss improved from 0.02547 to 0.02457, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0837 - accuracy: 0.9821 - val_loss: 0.0246 - val_accuracy: 0.9937
# Epoch 29/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0733 - accuracy: 0.9826
# Epoch 29: val_loss did not improve from 0.02457
# 27/27 [==============================] - 2s 56ms/step - loss: 0.0718 - accuracy: 0.9833 - val_loss: 0.0306 - val_accuracy: 0.9875
# Epoch 30/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9845
# Epoch 30: val_loss improved from 0.02457 to 0.02446, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 59ms/step - loss: 0.0641 - accuracy: 0.9845 - val_loss: 0.0245 - val_accuracy: 0.9937
# Epoch 31/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0818 - accuracy: 0.9764
# Epoch 31: val_loss improved from 0.02446 to 0.02374, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 58ms/step - loss: 0.0799 - accuracy: 0.9773 - val_loss: 0.0237 - val_accuracy: 0.9937
# Epoch 32/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9773
# Epoch 32: val_loss improved from 0.02374 to 0.01201, saving model to best_model_C1.h5
# 27/27 [==============================] - 2s 63ms/step - loss: 0.0724 - accuracy: 0.9773 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 33/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9869
# Epoch 33: val_loss did not improve from 0.01201
# 27/27 [==============================] - 2s 59ms/step - loss: 0.0677 - accuracy: 0.9869 - val_loss: 0.0278 - val_accuracy: 0.9875
# Epoch 34/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9666
# Epoch 34: val_loss did not improve from 0.01201
# 27/27 [==============================] - 2s 64ms/step - loss: 0.0939 - accuracy: 0.9666 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 35/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9797
# Epoch 35: val_loss did not improve from 0.01201
# 27/27 [==============================] - 2s 62ms/step - loss: 0.0781 - accuracy: 0.9797 - val_loss: 0.0308 - val_accuracy: 0.9875
# Epoch 36/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9833
# Epoch 36: val_loss did not improve from 0.01201
# 27/27 [==============================] - 2s 63ms/step - loss: 0.0552 - accuracy: 0.9833 - val_loss: 0.0209 - val_accuracy: 0.9875
# Epoch 37/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9809
# Epoch 37: val_loss did not improve from 0.01201
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0526 - accuracy: 0.9809 - val_loss: 0.0201 - val_accuracy: 0.9937
# Epoch 37: early stopping
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0335 - accuracy: 0.9890
# Test Loss: 0.0335334949195385
# Test Accuracy: 0.9890109896659851

# %%
# Graficar precisión y pérdida
plt.figure(figsize=(12, 5))

# Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Línea para Test
plt.title('Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.text(len(history.history['accuracy']) - 1, test_accuracy, f'Test Accuracy: {test_accuracy:.2f}', color='r', ha='center')


# Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')  # Línea para Test
plt.title('Cross Entropy Loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.text(len(history.history['loss']) - 1, test_loss, f'Test Loss: {test_loss:.2f}', color='r', ha='center')

plt.show()
